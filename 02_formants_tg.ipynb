# %% [markdown]
# # Create .csv for CBAS word list data
#
# Dataframes for female and male data are concatenated to yield a single dataframe of word list elicitations from CBAS.

# %%
import pandas as pd
import os
from audiolabel import read_label

# %% [markdown]
# ## Import textgrids

# %%
cbasdf = pd.DataFrame({
    'relpath': 'textgrids/cbas',
    'fname': ['p112.TextGrid',
              'p119.TextGrid',
              'p113.TextGrid',
              'p115.TextGrid',
              'p120.TextGrid',
              'p124.TextGrid'],
    'subject': ['p112', 'p119', 'p113', 'p115', 'p120', 'p124']
})

dimedf = pd.DataFrame({
    'relpath': 'textgrids/dime',
    'fname' : os.listdir("textgrids/dime")})
dimedf['subject'] = dimedf['fname'].apply(lambda x: x[:4])

tgdf = pd.concat([cbasdf, dimedf], ignore_index = True)

# %%
# inputs 

def tg2df(row):
    '''Load 'phone' and 'word' tiers from a textgrid and merge them.
    
    Parameters
    ----------
    
    row: named tuple
    A namedtuple as provided by `itertuples` that can be used to load a Praat
    textgrid from a path identified by row.relpath and row.fname. The textgrid is
    expected to have 'phone' and 'word' tiers.

    Returns
    -------
    
    mergedf: the merged dataframe.
    '''
    [wddf, phdf] = read_label(
        os.path.join(row.relpath, row.fname).replace("\\","/"),
        ftype='praat',
        tiers=['word', 'phone']
    )
    # Throw an error if tiers are not strictly hierarchical.
    # words contain phones
    assert(wddf.t1.isin(phdf.t1).all())
    assert(wddf.t2.isin(phdf.t2).all())
    
    # Add phone duration and speaker
    phdf['dur_ph'] = phdf.t2 - phdf.t1
    phdf['Participant'] = row.subject

    # Merge phone and word tiers.
    phwddf = pd.merge_asof(
        phdf.rename({'t1': 't1_ph', 't2': 't2_ph'}, axis='columns'),
        wddf.drop('fname', axis='columns') \
            .rename({'t1': 't1_wd', 't2': 't2_wd'}, axis='columns'),
        left_on='t1_ph',
        right_on='t1_wd'
    )

    # Add word-init and -final columns
    phwddf['is_wdinit_ph'] = phwddf.t1_ph == phwddf.t1_wd
    phwddf['is_wdfin_ph'] = phwddf.t2_ph == phwddf.t2_wd

    # Merge context tier and return the result.
    return phwddf

# %%
dflist = [tg2df(row) for row in tgdf.itertuples()]

# %%
alldf = pd.concat(dflist, ignore_index=True)

alldf.sample(10)
# Out:
#          t1_ph    t2_ph phone                           fname  dur_ph  \
# 15693    0.846    0.933     a  textgrids/dime/s05331.TextGrid   0.087
# 18341    1.118    1.207     k  textgrids/dime/s05524.TextGrid   0.089
# 12627    2.776    2.832     i  textgrids/dime/s05124.TextGrid   0.056
# 5139   238.143  238.273     a    textgrids/cbas/p120.TextGrid   0.130
# 22448    4.358    4.454     n  textgrids/dime/s05644.TextGrid   0.096
# 7735     0.255    0.371     a  textgrids/dime/s00131.TextGrid   0.116
# 17317    1.584    1.671     n  textgrids/dime/s05507.TextGrid   0.087
# 4724   109.751  111.439    sp    textgrids/cbas/p120.TextGrid   1.688
# 2277    37.984   38.044     a    textgrids/cbas/p113.TextGrid   0.060
# 9173     1.695    1.781     p  textgrids/dime/s00211.TextGrid   0.086
#
#       Participant    t1_wd    t2_wd         word  is_wdinit_ph  is_wdfin_ph
# 15693        s053    0.584    1.149     prosaica         False        False
# 18341        s055    1.118    1.444         cada          True        False
# 12627        s051    2.529    2.885       brasil         False        False
# 5139         p120  237.783  238.473      general         False        False
# 22448        s056    4.292    4.454           en         False         True
# 7735         s001    0.074    0.723   citatorios         False        False
# 17317        s055    1.584    1.758           no          True        False
# 4724         p120  109.751  111.439                       True         True
# 2277         p113   37.834   38.534    amarillas         False        False
# 9173         s002    1.613    2.098  repu_7blica         False        False

# %% [markdown]
# Create cols `prev_ph` and `next_ph` containing previous and following phones.

# %%
alldf['prev_ph'] = alldf.phone.shift(1).fillna('')
alldf['next_ph'] = alldf.phone.shift(-1).fillna('')
alldf = alldf[alldf["phone"]!=""]
alldf = alldf.reset_index(drop = True)

# %%
alldf
# Out:
#        t1_ph  t2_ph phone                           fname  dur_ph Participant  \
# 0      0.000  0.710   sil    textgrids/cbas/p112.TextGrid   0.710        p112
# 1      0.710  0.820     b    textgrids/cbas/p112.TextGrid   0.110        p112
# 2      0.820  0.920     a    textgrids/cbas/p112.TextGrid   0.100        p112
# 3      0.920  1.000     x    textgrids/cbas/p112.TextGrid   0.080        p112
# 4      1.000  1.140     o    textgrids/cbas/p112.TextGrid   0.140        p112
# ...      ...    ...   ...                             ...     ...         ...
# 22107  5.368  5.432     k  textgrids/dime/s05650.TextGrid   0.064        s056
# 22108  5.432  5.525     t  textgrids/dime/s05650.TextGrid   0.093        s056
# 22109  5.525  5.584     o  textgrids/dime/s05650.TextGrid   0.059        s056
# 22110  5.584  5.622    r(  textgrids/dime/s05650.TextGrid   0.038        s056
# 22111  5.622  5.781  .sil  textgrids/dime/s05650.TextGrid   0.159        s056
#
#        t1_wd  t2_wd    word  is_wdinit_ph  is_wdfin_ph prev_ph next_ph
# 0      0.000  0.710                  True         True               b
# 1      0.710  1.140    bajo          True        False     sil       a
# 2      0.710  1.140    bajo         False        False       b       x
# 3      0.710  1.140    bajo         False        False       a       o
# 4      0.710  1.140    bajo         False         True       x      sp
# ...      ...    ...     ...           ...          ...     ...     ...
# 22107  5.185  5.622  sector         False        False       e       t
# 22108  5.185  5.622  sector         False        False       k       o
# 22109  5.185  5.622  sector         False        False       t      r(
# 22110  5.185  5.622  sector         False         True       o    .sil
# 22111  5.622  5.781    .sil          True         True      r(
#
# [22112 rows x 13 columns]

# %%
# save df

alldf.to_csv("data/all_phones.csv", index = False)

# %% [markdown]
# ## Import formant data

# %%
# import cbas female
cbas_fem = pd.read_csv("data/cbas_female_formants.txt", sep = "\t")
cbas_fem = cbas_fem.rename(columns = {"Filename": "Participant",
                           "Segment label":"phone"})
cbas_fem["Gender"] = "Female"
cbas_fem["Corpus"] = "CBAS"

# import cbas male
cbas_male = pd.read_csv("data/cbas_male_formants.txt", sep = "\t")
cbas_male = cbas_male.rename(columns = {"Filename": "Participant",
                           "Segment label":"phone"})
cbas_male["Gender"] = "Male"
cbas_male["Corpus"] = "CBAS"

# combine cbas female and male
cbas = pd.concat([cbas_male, cbas_fem], ignore_index = True)
cbas.head()
# Out:
#   Participant phone        F1.50        F2.50        F3.50        F1.25  \
# 0        p112   sil  1349.549295  2591.478429  3249.782912  1640.246420
# 1        p112     b   538.241047  1256.248187  2799.236009   884.928365
# 2        p112     a   695.790976  1139.953282  2667.258621   689.324612
# 3        p112     x   751.966861  1524.518652  2973.220585   702.809393
# 4        p112     o   423.620505   737.502557  2374.974921   438.929950
#
#          F2.25        F3.25       F1.75        F2.75        F3.75 Gender  \
# 0  2418.644376  3493.133471  703.933103  2157.879849  2892.455533   Male
# 1  2273.697186  3419.016247  203.380184   972.145970  2675.148493   Male
# 2   840.183174  2738.685252  672.665361  1108.588353  2626.355793   Male
# 3  1206.953717  2902.094060  765.207925  1004.810302  2809.626524   Male
# 4   803.823366  2369.001274  442.314537   785.356913  2490.718660   Male
#
#   Corpus
# 0   CBAS
# 1   CBAS
# 2   CBAS
# 3   CBAS
# 4   CBAS

# %%
# import dime female
dime_fem = pd.read_csv("data/dime_female_formants.txt", sep = "\t")
dime_fem = dime_fem.rename(columns = {"Filename": "Participant",
                           "Segment label":"phone"})
dime_fem["Gender"] = "Female"
dime_fem["Corpus"] = "DIMEx100"

# import dime male
dime_male = pd.read_csv("data/dime_male_formants.txt", sep = "\t")
dime_male = dime_male.rename(columns = {"Filename": "Participant",
                           "Segment label":"phone"})
dime_male["Gender"] = "Male"
dime_male["Corpus"] = "DIMEx100"

dime = pd.concat([dime_male, dime_fem], ignore_index = True)
dime.head()
# Out:
#   Participant phone               F1.50               F2.50  \
# 0      s00101     e   355.2633477885047  2082.6287277489873
# 1      s00101     n  264.26283791989255   1352.960148040204
# 2      s00101     e   408.2120379191299  1773.8873587391736
# 3      s00101     l   297.3418407194621  1793.8137717606335
# 4      s00101     k  1724.5663340780563  2133.3977605820296
#
#                 F3.50               F1.25               F2.25  \
# 0  2606.7122225295493   432.2855807947169   2111.016626172527
# 1   2493.050542796756  256.35403799952866  1351.2672023829266
# 2  2705.2028782344655   345.6710062207199   1783.636308558772
# 3   2414.063185907122   303.8681945988882  2068.7748774752845
# 4   3206.997014599973  453.95221757590934  1868.9915807418786
#
#                 F3.25               F1.75               F2.75  \
# 0  2564.7035332058354  327.22694999240707  1921.1373374597447
# 1  2497.6198015702744   277.3963325271278  1513.0240015190643
# 2   2586.463559233574   422.0806104713125  1734.7389659592388
# 3  2693.6862198043245   297.0997307147349   1994.629593841888
# 4   2532.047138366204    1257.87458143167   1749.567600959356
#
#                 F3.75 Gender    Corpus
# 0   2745.610286846611   Male  DIMEx100
# 1   2515.159279522293   Male  DIMEx100
# 2  2716.0998083458703   Male  DIMEx100
# 3  2278.6034707710114   Male  DIMEx100
# 4  2656.2880070602605   Male  DIMEx100

# %%
# combine cbas and dime, female and male
formants = pd.concat([cbas, dime], ignore_index = True)
formants
# Out:
#       Participant phone               F1.50               F2.50  \
# 0            p112   sil             1349.55             2591.48
# 1            p112     b             538.241             1256.25
# 2            p112     a             695.791             1139.95
# 3            p112     x             751.967             1524.52
# 4            p112     o             423.621             737.503
# ...           ...   ...                 ...                 ...
# 22107      s05650     k   1165.100807346732  2426.3920041797787
# 22108      s05650     t  1126.8852770868596  2027.6264468532945
# 22109      s05650     o  435.91077915763856  1352.6603942285858
# 22110      s05650    r(  187.95601391927022   1466.034875716236
# 22111      s05650  .sil  1031.4921159766006  2354.4107938318834
#
#                     F3.50    F1.25    F2.25    F3.25               F1.75  \
# 0                 3249.78  1640.25  2418.64  3493.13             703.933
# 1                 2799.24  884.928   2273.7  3419.02              203.38
# 2                 2667.26  689.325  840.183  2738.69             672.665
# 3                 2973.22  702.809  1206.95  2902.09             765.208
# 4                 2374.97   438.93  803.823     2369             442.315
# ...                   ...      ...      ...      ...                 ...
# 22107  3470.2768848317864  1423.63  2836.48  4490.62   1024.578525310766
# 22108  3328.2844082332117  860.457  1951.17   3195.8  1142.4562588933588
# 22109   3158.138847527358  418.333  1522.29  3062.46   410.0946932152609
# 22110   2744.761849555006  312.541  1379.25  2685.89   300.7082730988796
# 22111  3734.9593123942473  380.627  1868.77  2883.97  1049.8444119582082
#
#                     F2.75               F3.75  Gender    Corpus
# 0                 2157.88             2892.46    Male      CBAS
# 1                 972.146             2675.15    Male      CBAS
# 2                 1108.59             2626.36    Male      CBAS
# 3                 1004.81             2809.63    Male      CBAS
# 4                 785.357             2490.72    Male      CBAS
# ...                   ...                 ...     ...       ...
# 22107  1736.3660434388864  3247.1437918433794  Female  DIMEx100
# 22108   2322.173941161411  3251.5501199831447  Female  DIMEx100
# 22109   1370.264611031101   3089.980191544936  Female  DIMEx100
# 22110  1511.2612699396043  2839.9733575529513  Female  DIMEx100
# 22111  2116.2543455121654  3270.7120934693585  Female  DIMEx100
#
# [22112 rows x 13 columns]

# %% [markdown]
# ## Merge formant and textgrid data

# %%
data = formants.merge(alldf, left_index = True, right_index = True, how = "outer")
data = data.drop(["Participant_y", "phone_y"], axis = 1)
data = data.rename(columns = {"Participant_x": "Participant",
                             "phone_x": "phone"})
data.sample(10)
# Out:
#       Participant phone               F1.50               F2.50  \
# 9547       s00224     k  481.98244744429394   1767.103486358395
# 19650      s05606     o    421.419753072062   1101.849822891012
# 301          p112     l             353.783             1292.53
# 14887      s05324     k  1189.4006769871194  1534.9625414935242
# 17237      s05516     a   672.2371843317133  1897.8426051845058
# 8314       s00147     k   394.7344391487064  1158.4236249937792
# 5428         p124     a             671.957             1382.66
# 15841      s05342     u    265.755884796343   946.7870562767508
# 8368       s00148     o  457.60400433453054  1454.7049580962798
# 21190      s05633     b   478.3019661286474  1724.0807282621643
#
#                     F3.50               F1.25               F2.25  \
# 9547    2721.280626437371   326.3743013702274  1748.7101579487044
# 19650  2784.4627567307975              405.62             1049.49
# 301               2457.88               336.3             1044.69
# 14887  3407.4125412713997             1325.32             2348.76
# 17237  2985.7865954224903             658.839             1925.25
# 8314    2189.334160840481  389.27900131931335  1723.6981304438755
# 5428              2623.39             710.715             1790.12
# 15841   2608.844040169354             264.987             906.816
# 8368    2250.649836832399   417.4161264403868   1512.823385548078
# 21190   2886.862009623848              506.33             1716.04
#
#                     F3.25              F1.75               F2.75  ...   t2_ph  \
# 9547   2543.0180297688003  862.3625452694424   1743.075853539593  ...   2.979
# 19650             2881.33  378.4998442461492   1218.842856039796  ...   3.286
# 301               2554.79            341.003             1180.07  ...  84.917
# 14887             3756.53  523.2828503531581  1907.6230072201668  ...   1.478
# 17237             2938.23  524.8781816606086   1665.004900406051  ...   3.768
# 8314    2380.361985924618  697.4221221333216  1855.2181904198212  ...   2.648
# 5428              3096.76            777.852             1865.68  ...  56.912
# 15841             2517.64   271.187057058045  1091.0008183693938  ...   1.397
# 8368     2314.94715162769  375.8736792368944  1348.1145376485756  ...   3.460
# 21190                2880  520.5699350140468  1771.2360641283633  ...   0.239
#
#                                 fname dur_ph   t1_wd   t2_wd           word  \
# 9547   textgrids/dime/s00224.TextGrid  0.090   2.889   3.033            que
# 19650  textgrids/dime/s05606.TextGrid  0.074   2.447   3.381  identificamos
# 301      textgrids/cbas/p112.TextGrid  0.140  84.377  84.917          nivel
# 14887  textgrids/dime/s05324.TextGrid  0.077   1.401   1.956     cli_7nicos
# 17237  textgrids/dime/s05516.TextGrid  0.085   3.529   4.383       ecatepec
# 8314   textgrids/dime/s00147.TextGrid  0.040   2.608   3.161       cuaresma
# 5428     textgrids/cbas/p124.TextGrid  0.060  56.852  57.512         amigas
# 15841  textgrids/dime/s05342.TextGrid  0.057   1.125   1.786    preguntamos
# 8368   textgrids/dime/s00148.TextGrid  0.075   3.095   3.460        adriano
# 21190  textgrids/dime/s05633.TextGrid  0.036   0.060   0.379          deben
#
#        is_wdinit_ph  is_wdfin_ph  prev_ph next_ph
# 9547           True        False        s       e
# 19650         False        False        m       s
# 301           False         True        e      sp
# 14887          True        False        s       l
# 17237         False        False        k       t
# 8314           True        False        e       u
# 5428           True        False        s       m
# 15841         False        False        g       n
# 8368          False         True        n       n
# 21190         False        False        e       e
#
# [10 rows x 24 columns]

# %%
import re

# fix phones from txt file, remove + following some vowels
data["phone"] = data["phone"].apply(lambda x: re.sub("([aeiou])\+", "\1", x))

# replace `r(` with `rf` for consistency
data['word'] = data['word'].apply(lambda x: re.sub("r\(", "rf", x))

# fix notation in dimex corpus, where V_7 yields accented V
data['word'] = data['word'].apply(lambda x: re.sub("a_7", "á", x))
data['word'] = data['word'].apply(lambda x: re.sub("i_7", "í", x))
data['word'] = data['word'].apply(lambda x: re.sub("o_7", "ó", x))
data['word'] = data['word'].apply(lambda x: re.sub("u_7", "ú", x))
data['word'] = data['word'].apply(lambda x: re.sub("e_7", "é", x))

# fix tildas
data['word'] = data['word'].apply(lambda x: re.sub("n~", "ñ", x))

# remove phones `sp` and `.sil`
data = data[(data['phone'] != ".sil") & (data['phone'] != "sp")]

data = data.reset_index(drop = True)

# %%
data.sample(25)
# Out:
#       Participant phone               F1.50               F2.50  \
# 8990       s00230     e  423.37825123349893  1851.8583001258994
# 19050      s05618     a   740.6840866857959  1954.7858764317907
# 19483      s05624    rf   274.2701707127544   1898.851618891144
# 14032      s05329     t   523.1763256918192   1430.007400707782
# 7224       s00141     n   280.6582818103457  1860.6233681844226
# 363          p112     e             440.467             1597.53
# 13831      s05323     d   278.7631574469382  1469.5596465157728
# 19722      s05628     e  285.55312625676316   2677.662581301646
# 15635      s05506     s  1074.2674831100715  2153.5311146813724
# 1193         p119     e             520.773             1622.32
# 5739       s00103     n    255.014007892284   1548.557729789045
# 18753      s05612     e   619.5283044748327  2387.2203341366753
# 13837      s05323     e  445.37168025717205   2478.980743520157
# 8804       s00227     s  1615.6084116414852   2687.685662610277
# 14217      s05332     n   266.6801279030777  1695.9529809854714
# 11087      s05120     a   781.9170050794065   1661.550796496361
# 10549      s05112     i   428.5563810003857  1810.1846753116133
# 15829      s05510     l   394.1081864651684  1946.0241651450222
# 2384         p113     D             594.768             1338.62
# 1289         p119     a             734.014             1535.85
# 3456         p115     e             613.602             1124.11
# 1718         p119     D             440.412             1532.74
# 4601         p120     i             288.009             660.522
# 9044       s00231    rf   382.8685989411324  1527.2810274599155
# 1578         p119     k             1188.09             1612.69
#
#                     F3.50               F1.25               F2.25  \
# 8990    2620.058628632856   417.0612015299634   1653.050064897118
# 19050  2998.5703040604258             681.677             1896.27
# 19483  2818.8939015008955             294.055             2070.17
# 14032  2922.9616460352195             525.836             1378.03
# 7224   2423.1494665106793  280.23067291376884  1896.1609887444458
# 363               2337.95             418.256             1650.51
# 13831   3138.358934056901             314.704             1337.99
# 19722   3162.295525404391             315.333             2733.75
# 15635  3219.5667696434475             872.173             1983.17
# 1193              2514.33             529.169             1589.14
# 5739   2436.9091584779594  244.75140805029199  1528.0187206995388
# 18753  3365.8781170812485              467.77                1531
# 13837  3034.6799875343568              492.71             2377.57
# 8804   3753.9250162692383   541.3101187068114  1602.4794598831556
# 14217  3050.7085913835213             264.929              1522.7
# 11087  2325.2536742911484             737.971             1452.24
# 10549   2466.788740399145             376.248             1511.53
# 15829  3008.6033420730478             366.561              1923.6
# 2384              2835.99              798.46             1559.18
# 1289              2666.52             938.655             1715.83
# 3456              2480.55             1265.84             2620.84
# 1718              2377.46             437.998             1800.19
# 4601              2586.62             317.773              643.28
# 9044    2654.211788279119   367.4810679133915  1452.0845927314206
# 1578              2546.16             299.757             1337.64
#
#                     F3.25               F1.75               F2.75  ...  \
# 8990    2623.177836250595   361.5890784324881  2074.5579142443357  ...
# 19050             3001.27   700.6724979027721  1928.9630412384458  ...
# 19483             2655.28  289.26431114385724   1673.944452287678  ...
# 14032             2704.47   833.4660664457192  1949.5625827978056  ...
# 7224   2137.5617184659063   280.1631367584402  1856.9874353495104  ...
# 363               2501.15             458.886             1617.29  ...
# 13831             3197.55  395.28950020482506  1575.2458180809929  ...
# 19722             3228.78   279.9960968426973   2769.891567239376  ...
# 15635              3173.9  1401.9037049954804   2027.764311740703  ...
# 1193              2483.27             571.789             1646.01  ...
# 5739   2421.1262482538154  256.07798848172956  1601.9863965260759  ...
# 18753             2584.34    611.650079640885   863.9916804624219  ...
# 13837              3009.7   442.1255595152442    2352.21232546678  ...
# 8804    2751.175303125384   264.3862030225567  1638.4915359159397  ...
# 14217                3042   273.7901153691623  1982.5196005931607  ...
# 11087             2274.84   738.5195301737808  1748.7858302512734  ...
# 10549              2569.7   539.8442110614798  1949.3495855131496  ...
# 15829             2942.42  389.99079140167146   1865.795131875639  ...
# 2384              2629.97             616.608             1148.13  ...
# 1289              2801.12             703.724             1601.17  ...
# 3456              3653.69             566.426             895.541  ...
# 1718              2315.92             503.907             1430.42  ...
# 4601              2518.72              266.76             1165.92  ...
# 9044   2676.6295299738294  1474.5886221372843   2510.675332877708  ...
# 1578              2524.82             764.394             1607.96  ...
#
#          t2_ph                           fname dur_ph    t1_wd    t2_wd  \
# 8990     3.925  textgrids/dime/s00230.TextGrid  0.072    3.823    3.925
# 19050    3.048  textgrids/dime/s05618.TextGrid  0.039    2.906    3.633
# 19483    2.669  textgrids/dime/s05624.TextGrid  0.026    2.461    2.894
# 14032    0.282  textgrids/dime/s05329.TextGrid  0.071    0.060    0.670
# 7224     2.236  textgrids/dime/s00141.TextGrid  0.050    2.078    2.545
# 363    118.683    textgrids/cbas/p112.TextGrid  0.050  118.383  119.293
# 13831    1.853  textgrids/dime/s05323.TextGrid  0.050    1.803    1.853
# 19722    2.064  textgrids/dime/s05628.TextGrid  0.070    1.631    2.145
# 15635    1.517  textgrids/dime/s05506.TextGrid  0.081    1.436    1.745
# 1193    86.252    textgrids/cbas/p119.TextGrid  0.080   85.812   86.552
# 5739     0.337  textgrids/dime/s00103.TextGrid  0.050    0.137    0.337
# 18753    0.643  textgrids/dime/s05612.TextGrid  0.063    0.378    0.822
# 13837    2.330  textgrids/dime/s05323.TextGrid  0.081    1.853    2.575
# 8804     0.782  textgrids/dime/s00227.TextGrid  0.054    0.634    0.782
# 14217    0.397  textgrids/dime/s05332.TextGrid  0.040    0.223    0.762
# 11087    1.207  textgrids/dime/s05120.TextGrid  0.048    1.096    1.300
# 10549    1.903  textgrids/dime/s05112.TextGrid  0.029    1.470    1.995
# 15829    2.219  textgrids/dime/s05510.TextGrid  0.097    1.800    2.576
# 2384   187.392    textgrids/cbas/p113.TextGrid  0.220  186.742  187.662
# 1289   114.474    textgrids/cbas/p119.TextGrid  0.090  114.384  114.894
# 3456   185.160    textgrids/cbas/p115.TextGrid  0.080  185.080  185.780
# 1718   252.220    textgrids/cbas/p119.TextGrid  0.120  251.780  252.360
# 4601   288.204    textgrids/cbas/p120.TextGrid  0.090  287.794  288.484
# 9044     2.738  textgrids/dime/s00231.TextGrid  0.051    2.604    3.130
# 1578   205.167    textgrids/cbas/p119.TextGrid  0.080  204.877  205.857
#
#                word  is_wdinit_ph  is_wdfin_ph  prev_ph next_ph
# 8990             de         False         True        d       k
# 19050  calificación         False        False        k       l
# 19483       periodo         False        False        e       i
# 14032     postgrado         False        False        o       s
# 7224      principio         False        False        i       s
# 363    intervención         False        False        t      rf
# 13831            de          True         True        o       a
# 19722       jóvenes         False        False        n       s
# 15635         sobre          True        False        a       o
# 1193        balsero         False        False        s      rf
# 5739            sin         False         True        i       e
# 18753        tiende         False        False        i       n
# 13837    asistencia         False        False        t       n
# 8804            las         False         True        a       n
# 14217     considera         False        False        o       s
# 11087          para         False        False        p      r(
# 10549       ciencia         False        False        s       a
# 15829   privilegios         False        False        i       e
# 2384      olvidados         False        False        a       o
# 1289           azul          True        False       sp       T
# 3456     encadenado          True        False       sp      ng
# 1718         válido         False        False        i       o
# 4601       servicio         False        False        b       s
# 9044        trabajo         False        False        t       a
# 1578     encadenado         False        False       ng       a
#
# [25 rows x 24 columns]

# %%
# fix naming of participant col
data["Participant"] = data["Participant"].apply(lambda x: x[:4])

# %%
data.to_csv("data/alldata.csv", index = False)

# %%
# remove rows not containing vowels
vowelsdf = data[(data['phone']=="a") | 
                 (data['phone']=="e") | 
                 (data['phone']=="i") | 
                 (data['phone']=="u") | 
                 (data['phone']=="o")]
vowelsdf = vowelsdf.reset_index(drop = True)
vowelsdf = vowelsdf.rename(columns = {"phone": "Vowel"})
len(vowelsdf)
# Out:
# 9289

# %%
vowelsdf.to_csv("data/allvowels.csv", index = False)
