# %% [markdown]
# # Exploratory analyses

# %%
import pandas as pd

# %%
# import data
df = pd.read_csv("data/balancednormdata.csv")

# %% [markdown]
# First, calculate the median `F1.50_norm` and `F2.50_norm` by `Vowel` for each `Participant`.

# %%
# for creating a table in paper
df.groupby(["Corpus", "Gender", "Vowel"])[["F1.50_norm", "F2.50_norm"]].agg(["mean", "std"])
# Out:
#                       F1.50_norm           F2.50_norm
#                             mean       std       mean       std
# Corpus   Gender Vowel
# CBAS     Female a       0.690153  0.078677   1.440400  0.160557
#                 e       0.522196  0.044102   1.639447  0.360626
#                 i       0.363788  0.073881   1.509845  0.712785
#                 o       0.513432  0.099156   1.004990  0.271400
#                 u       0.353459  0.075293   1.000293  0.273739
#          Male   a       0.642233  0.073389   1.350621  0.167825
#                 e       0.495278  0.064839   1.718878  0.176660
#                 i       0.420471  0.056701   2.118412  0.197966
#                 o       0.446486  0.057099   0.948819  0.134466
#                 u       0.384613  0.034018   0.914845  0.156361
# DIMEx100 Female a       0.629476  0.084176   1.550697  0.124951
#                 e       0.444645  0.064790   1.776542  0.186068
#                 i       0.296804  0.049485   2.190890  0.194906
#                 o       0.449449  0.080947   1.203993  0.169982
#                 u       0.327072  0.047106   1.093127  0.181769
#          Male   a       0.588736  0.079945   1.531281  0.121924
#                 e       0.416584  0.044667   1.801057  0.147522
#                 i       0.301354  0.038094   2.192451  0.179746
#                 o       0.430107  0.050041   1.152144  0.173928
#                 u       0.330354  0.030398   1.202872  0.185936

# %%
# for plotting in R
vowel_plot = df.groupby(["Corpus", "Gender", "Vowel"])[["F1.50_norm", "F2.50_norm"]].mean()
vowel_plot = vowel_plot.reset_index()
vowel_plot
# Out:
#       Corpus  Gender Vowel  F1.50_norm  F2.50_norm
# 0       CBAS  Female     a    0.690153    1.440400
# 1       CBAS  Female     e    0.522196    1.639447
# 2       CBAS  Female     i    0.363788    1.509845
# 3       CBAS  Female     o    0.513432    1.004990
# 4       CBAS  Female     u    0.353459    1.000293
# 5       CBAS    Male     a    0.642233    1.350621
# 6       CBAS    Male     e    0.495278    1.718878
# 7       CBAS    Male     i    0.420471    2.118412
# 8       CBAS    Male     o    0.446486    0.948819
# 9       CBAS    Male     u    0.384613    0.914845
# 10  DIMEx100  Female     a    0.629476    1.550697
# 11  DIMEx100  Female     e    0.444645    1.776542
# 12  DIMEx100  Female     i    0.296804    2.190890
# 13  DIMEx100  Female     o    0.449449    1.203993
# 14  DIMEx100  Female     u    0.327072    1.093127
# 15  DIMEx100    Male     a    0.588736    1.531281
# 16  DIMEx100    Male     e    0.416584    1.801057
# 17  DIMEx100    Male     i    0.301354    2.192451
# 18  DIMEx100    Male     o    0.430107    1.152144
# 19  DIMEx100    Male     u    0.330354    1.202872

# %%
vowel_plot.to_csv("plot_model/area_plot.csv", index = False)

# %%
# add duration_norm, duration_ms and duration_log cols
vowel_model = df.copy()
vowel_model["Dur_ms"] = vowel_model["dur_ph"].apply(lambda x: x*1000)
vowel_model["Dur_norm"] = vowel_model["Dur_ms"] * vowel_model["Speech Rate"]
vowel_model["Dur_log"] = vowel_model["Dur_ms"].apply(lambda x: math.log(x))

# %%
vowel_model.to_csv("plot_model/vowel_model.csv", index = False)

# %% [markdown]
# ## Vowel space area by speaker

# %%
parts = df.groupby(["Participant", "Vowel"])[["F1.50_norm", "F2.50_norm"]].mean()
parts_dict = parts.groupby(level=0).apply(lambda parts: parts.xs(parts.name).to_dict()).to_dict()
parts_dict
# Out:
# {'p112': {'F1.50_norm': {'a': 0.6277432295294227,
#    'e': 0.45249439162084304,
#    'i': 0.38787887295781504,
#    'o': 0.43235958909509203,
#    'u': 0.38076868657335117},
#   'F2.50_norm': {'a': 1.3466508265490336,
#    'e': 1.8272374625426173,
#    'i': 2.2767362369181785,
#    'o': 0.8970828050414119,
#    'u': 0.8138116231867631}},
#  'p113': {'F1.50_norm': {'a': 0.6925982470276436,
#    'e': 0.5576053462214523,
#    'i': 0.41129617314830963,
#    'o': 0.5329422143127972,
#    'u': 0.37350956957989706},
#   'F2.50_norm': {'a': 1.460948020705278,
#    'e': 1.750439550135898,
#    'i': 1.5338558344829991,
#    'o': 0.901101866423492,
#    'u': 0.8281231993962865}},
#  'p115': {'F1.50_norm': {'a': 0.682382598990521,
#    'e': 0.5335102099954813,
#    'i': 0.4134488754970261,
#    'o': 0.5263231140564589,
#    'u': 0.42835687831170666},
#   'F2.50_norm': {'a': 1.5377428666535964,
#    'e': 1.4542072611000627,
#    'i': 1.0293834575205194,
#    'o': 1.102312170977519,
#    'u': 1.1693400928477862}},
#  'p119': {'F1.50_norm': {'a': 0.6560749284687362,
#    'e': 0.5350063658812744,
#    'i': 0.4500303992617882,
#    'o': 0.46494175932447035,
#    'u': 0.3881076043774522},
#   'F2.50_norm': {'a': 1.354414314387703,
#    'e': 1.6182591451948503,
#    'i': 1.974815287464657,
#    'o': 1.0164095791130632,
#    'u': 1.0066927870601725}},
#  'p120': {'F1.50_norm': {'a': 0.717317350958904,
#    'e': 0.4846336757867856,
#    'i': 0.318090963896802,
#    'o': 0.5153328501002826,
#    'u': 0.2700157477132252},
#   'F2.50_norm': {'a': 1.3469070643297831,
#    'e': 1.6360970845827265,
#    'i': 1.4886220766990166,
#    'o': 1.0746997720833609,
#    'u': 0.7374179914078948}},
#  'p124': {'F1.50_norm': {'a': 0.6623009907264366,
#    'e': 0.5161685547747661,
#    'i': 0.3095887526736911,
#    'o': 0.4782422743355397,
#    'u': 0.3417027630602927},
#   'F2.50_norm': {'a': 1.423848892898525,
#    'e': 1.747836783616403,
#    'i': 2.0340207429253887,
#    'o': 0.9458082404905737,
#    'u': 1.1930953240706528}},
#  's001': {'F1.50_norm': {'a': 0.5653296027448342,
#    'e': 0.42604593132413926,
#    'i': 0.30287461726062176,
#    'o': 0.4472933222744851,
#    'u': 0.32951666457857187},
#   'F2.50_norm': {'a': 1.5897893271855206,
#    'e': 1.7842550946031144,
#    'i': 2.115636814337525,
#    'o': 1.2050172752598813,
#    'u': 1.266542183822359}},
#  's002': {'F1.50_norm': {'a': 0.6080402594629056,
#    'e': 0.40842625227192497,
#    'i': 0.29968529147248435,
#    'o': 0.4144369494491982,
#    'u': 0.3311385961496457},
#   'F2.50_norm': {'a': 1.483026160141017,
#    'e': 1.8155420938016313,
#    'i': 2.2767593533368324,
#    'o': 1.1039351142253193,
#    'u': 1.143180737714276}},
#  's051': {'F1.50_norm': {'a': 0.6795954487152237,
#    'e': 0.4614584304120434,
#    'i': 0.2842453535974878,
#    'o': 0.5092171057317542,
#    'u': 0.32423982122580214},
#   'F2.50_norm': {'a': 1.5367784803860443,
#    'e': 1.7756186327082322,
#    'i': 2.1589776564811807,
#    'o': 1.2690042441408904,
#    'u': 1.1278470963569667}},
#  's053': {'F1.50_norm': {'a': 0.6167032801470674,
#    'e': 0.41201020046901365,
#    'i': 0.27520021172816567,
#    'o': 0.3950573028113076,
#    'u': 0.3033269594319107},
#   'F2.50_norm': {'a': 1.51050983950014,
#    'e': 1.8165593387453878,
#    'i': 2.254810545903299,
#    'o': 1.1274501696246682,
#    'u': 1.071383858443445}},
#  's055': {'F1.50_norm': {'a': 0.5769649087607002,
#    'e': 0.46916305894754967,
#    'i': 0.36053329900857745,
#    'o': 0.4767836426843124,
#    'u': 0.36813134499061684},
#   'F2.50_norm': {'a': 1.5377957840248841,
#    'e': 1.714400636450589,
#    'i': 2.0910239376757667,
#    'o': 1.2482388921179333,
#    'u': 1.113533636853105}},
#  's056': {'F1.50_norm': {'a': 0.6505578312997028,
#    'e': 0.4321028209642887,
#    'i': 0.26780917134839693,
#    'o': 0.4115750030053701,
#    'u': 0.3050805874311276},
#   'F2.50_norm': {'a': 1.6263100991685955,
#    'e': 1.8072683993290337,
#    'i': 2.2593491103752816,
#    'o': 1.1640623839666084,
#    'u': 1.0642569144613012}}}

# %%
# takes dicts in form {participant: {F1: {a: formant, e: formant, etc.}, F2: {a: etc.}}}
import math

def PolygonArea(d):
    areas = {}
    
    def area(a, b, c):
        def distance(p1, p2):
            return math.hypot(p1[0]-p2[0], p1[1]-p2[1])

        side_a = distance(a, b)
        side_b = distance(b, c)
        side_c = distance(c, a)
        s = 0.5 * ( side_a + side_b + side_c)
        return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))
    
    for p in d.keys():
        # coordinates in form (-F2, -F1)
        a = (d[p]["F2.50_norm"]["a"], d[p]["F1.50_norm"]["a"])
        e = (d[p]["F2.50_norm"]["e"], d[p]["F1.50_norm"]["e"])
        i = (d[p]["F2.50_norm"]["i"], d[p]["F1.50_norm"]["i"])
        o = (d[p]["F2.50_norm"]["o"], d[p]["F1.50_norm"]["o"])
        u = (d[p]["F2.50_norm"]["u"], d[p]["F1.50_norm"]["u"])
        
        a1 = area(a, e, o)
        a2 = area(e, o, u)
        a3 = area(i, e, u)
        
        areas[p] = a1 + a2 + a3
    return areas

# %%
parts_area = PolygonArea(parts_dict)
areas = pd.DataFrame.from_dict(parts_area, orient = "index").reset_index()
areas.columns = ["Participant", "Area"]
areas
# Out:
#    Participant      Area
# 0         p112  0.158360
# 1         p113  0.175239
# 2         p115  0.048606
# 3         p119  0.120630
# 4         p120  0.193921
# 5         p124  0.206452
# 6         s001  0.119608
# 7         s002  0.153924
# 8         s051  0.183478
# 9         s053  0.179042
# 10        s055  0.101953
# 11        s056  0.195086

# %%
# save into dataset
area_model = df.merge(areas, on = "Participant", how = "outer")
area_model.head(1)
# Out:
#   Participant Vowel       F1.50        F2.50        F3.50       F1.25  \
# 0        p112     a  695.790976  1139.953282  2667.258621  689.324612
#
#         F2.25        F3.25       F1.75        F2.75  ...  Delta F.50  \
# 0  840.183174  2738.685252  672.665361  1108.588353  ...  942.492654
#
#    Delta F.25  Delta F.75  F1.50_norm  F2.50_norm F1.25_norm  F2.25_norm  \
# 0  919.248109  938.576788    0.738246    1.209509   0.749879     0.91399
#
#    F1.75_norm  F2.75_norm     Area
# 0    0.716687    1.181138  0.15836
#
# [1 rows x 44 columns]

# %%
area_model.to_csv("plot_model/area_model.csv", index = False)

# %% [markdown]
# ## Add in vs centroid and category centroid by speaker

# %%
cent = df.groupby("Participant")[["F1.50_norm", "F2.50_norm"]].mean().reset_index()
cent.rename(columns={"F1.50_norm": "F1_mean", "F2.50_norm": "F2_mean"}, inplace = True)
cent
# Out:
#    Participant   F1_mean   F2_mean
# 0         p112  0.506871  1.426428
# 1         p113  0.574029  1.370420
# 2         p115  0.568055  1.340613
# 3         p119  0.555661  1.418055
# 4         p120  0.552560  1.339259
# 5         p124  0.522945  1.453591
# 6         s001  0.444156  1.637488
# 7         s002  0.450072  1.601071
# 8         s051  0.489975  1.640119
# 9         s053  0.432863  1.638171
# 10        s055  0.474940  1.585498
# 11        s056  0.448972  1.631898

# %%
vowel_means = df.groupby(["Participant", "Vowel"])[["F1.50_norm", "F2.50_norm"]].mean().reset_index()
vowel_means.rename(columns={"F1.50_norm": "F1_v", "F2.50_norm": "F2_v"}, inplace = True)
vowel_means.head()
# Out:
#   Participant Vowel      F1_v      F2_v
# 0        p112     a  0.627743  1.346651
# 1        p112     e  0.452494  1.827237
# 2        p112     i  0.387879  2.276736
# 3        p112     o  0.432360  0.897083
# 4        p112     u  0.380769  0.813812

# %%
dispersion = vowel_means.merge(cent, on = "Participant", how = "outer")
dispersion.sample(5)
# Out:
#    Participant Vowel      F1_v      F2_v   F1_mean   F2_mean
# 6         p113     e  0.557605  1.750440  0.574029  1.370420
# 54        s055     u  0.368131  1.113534  0.474940  1.585498
# 55        s056     a  0.650558  1.626310  0.448972  1.631898
# 10        p115     a  0.682383  1.537743  0.568055  1.340613
# 39        s002     u  0.331139  1.143181  0.450072  1.601071

# %%
import numpy as np

dispersion['Dispersion_v'] = np.sqrt((abs(dispersion["F1_mean"] - dispersion["F1_v"])**2) + (abs(dispersion["F2_mean"] - dispersion["F2_v"])**2))
disperse = dispersion.groupby("Participant")["Dispersion_v"].mean().reset_index()
disperse.rename(columns = {"Dispersion_v": "Dispersion"}, inplace = True)
disperse
# Out:
#    Participant  Dispersion
# 0         p112    0.513585
# 1         p113    0.361897
# 2         p115    0.231415
# 3         p119    0.348556
# 4         p120    0.335895
# 5         p124    0.376462
# 6         s001    0.319485
# 7         s002    0.415879
# 8         s051    0.364521
# 9         s053    0.426683
# 10        s055    0.316226
# 11        s056    0.417169

# %%
# save dispersion to dataset
disp_model = df.merge(disperse, on = "Participant", how = "outer")
disp_model.sample(5)
# Out:
#      Participant Vowel       F1.50        F2.50        F3.50       F1.25  \
# 436         p119     a  767.796459  1593.865521  2267.413095  906.944069
# 2155        s001     o  451.374176  1384.861925  2519.489421  455.245027
# 2271        s002     a  624.324819  1668.643788  2845.700972  713.182396
# 2108        s001     i  325.732626  2151.224239  2734.843928  377.134311
# 2181        s001     o  455.058337  1078.262643  2314.317285  445.005419
#
#             F2.25        F3.25        F1.75        F2.75  ...   Delta F.50  \
# 436   1785.014436  2977.308279   737.792737  1595.886732  ...  1084.219365
# 2155  1390.676055  2582.521616   430.935219  1427.828890  ...   966.374551
# 2271  1695.916039  2910.936903  1318.587822  2368.662874  ...  1046.087601
# 2108  2130.958011  2753.253901   330.399432  2060.386435  ...   966.374551
# 2181  1175.187545  2422.890899   472.050256  1110.584194  ...   966.374551
#
#       Delta F.25   Delta F.75  F1.50_norm  F2.50_norm F1.25_norm  F2.25_norm  \
# 436   1073.12413  1116.834981    0.708156    1.470058   0.845144    1.663381
# 2155   959.13929   962.433837    0.467080    1.433049   0.474639    1.449921
# 2271  1039.69639  1046.921418    0.596819    1.595128   0.685953    1.631165
# 2108   959.13929   962.433837    0.337067    2.226077   0.393201    2.221740
# 2181   959.13929   962.433837    0.470892    1.115781   0.463963    1.225252
#
#       F1.75_norm  F2.75_norm Dispersion
# 436     0.660610    1.428937   0.348556
# 2155    0.447756    1.483561   0.319485
# 2271    1.259491    2.262503   0.415879
# 2108    0.343296    2.140808   0.319485
# 2181    0.490476    1.153933   0.319485
#
# [5 rows x 44 columns]

# %%
disp_model.to_csv("plot_model/disp_model.csv", index = False)

# %%
# now create new set for disp plotting
disp_plot1 = df.groupby(["Corpus", "Gender", "Vowel"])[["F1.50_norm", "F2.50_norm"]].mean().reset_index()
disp_plot1.rename(columns = {"F1.50_norm": "F1_v", "F2.50_norm": "F2_v"}, inplace = True)
disp_plot1
# Out:
#       Corpus  Gender Vowel      F1_v      F2_v
# 0       CBAS  Female     a  0.690153  1.440400
# 1       CBAS  Female     e  0.522196  1.639447
# 2       CBAS  Female     i  0.363788  1.509845
# 3       CBAS  Female     o  0.513432  1.004990
# 4       CBAS  Female     u  0.353459  1.000293
# 5       CBAS    Male     a  0.642233  1.350621
# 6       CBAS    Male     e  0.495278  1.718878
# 7       CBAS    Male     i  0.420471  2.118412
# 8       CBAS    Male     o  0.446486  0.948819
# 9       CBAS    Male     u  0.384613  0.914845
# 10  DIMEx100  Female     a  0.629476  1.550697
# 11  DIMEx100  Female     e  0.444645  1.776542
# 12  DIMEx100  Female     i  0.296804  2.190890
# 13  DIMEx100  Female     o  0.449449  1.203993
# 14  DIMEx100  Female     u  0.327072  1.093127
# 15  DIMEx100    Male     a  0.588736  1.531281
# 16  DIMEx100    Male     e  0.416584  1.801057
# 17  DIMEx100    Male     i  0.301354  2.192451
# 18  DIMEx100    Male     o  0.430107  1.152144
# 19  DIMEx100    Male     u  0.330354  1.202872

# %%
disp_plot2 = df.groupby(["Corpus", "Gender"])[["F1.50_norm", "F2.50_norm"]].mean().reset_index()
disp_plot2.rename(columns = {"F1.50_norm": "F1_cent", "F2.50_norm": "F2_cent"}, inplace = True)
disp_plot2
# Out:
#      Corpus  Gender   F1_cent   F2_cent
# 0      CBAS  Female  0.554748  1.373808
# 1      CBAS    Male  0.531152  1.422261
# 2  DIMEx100  Female  0.461986  1.623247
# 3  DIMEx100    Male  0.447281  1.618256

# %%
disp_plot = disp_plot1.merge(disp_plot2, on = ["Corpus", "Gender"], how = "outer")
disp_plot
# Out:
#       Corpus  Gender Vowel      F1_v      F2_v   F1_cent   F2_cent
# 0       CBAS  Female     a  0.690153  1.440400  0.554748  1.373808
# 1       CBAS  Female     e  0.522196  1.639447  0.554748  1.373808
# 2       CBAS  Female     i  0.363788  1.509845  0.554748  1.373808
# 3       CBAS  Female     o  0.513432  1.004990  0.554748  1.373808
# 4       CBAS  Female     u  0.353459  1.000293  0.554748  1.373808
# 5       CBAS    Male     a  0.642233  1.350621  0.531152  1.422261
# 6       CBAS    Male     e  0.495278  1.718878  0.531152  1.422261
# 7       CBAS    Male     i  0.420471  2.118412  0.531152  1.422261
# 8       CBAS    Male     o  0.446486  0.948819  0.531152  1.422261
# 9       CBAS    Male     u  0.384613  0.914845  0.531152  1.422261
# 10  DIMEx100  Female     a  0.629476  1.550697  0.461986  1.623247
# 11  DIMEx100  Female     e  0.444645  1.776542  0.461986  1.623247
# 12  DIMEx100  Female     i  0.296804  2.190890  0.461986  1.623247
# 13  DIMEx100  Female     o  0.449449  1.203993  0.461986  1.623247
# 14  DIMEx100  Female     u  0.327072  1.093127  0.461986  1.623247
# 15  DIMEx100    Male     a  0.588736  1.531281  0.447281  1.618256
# 16  DIMEx100    Male     e  0.416584  1.801057  0.447281  1.618256
# 17  DIMEx100    Male     i  0.301354  2.192451  0.447281  1.618256
# 18  DIMEx100    Male     o  0.430107  1.152144  0.447281  1.618256
# 19  DIMEx100    Male     u  0.330354  1.202872  0.447281  1.618256

# %%
# save disp_plot
disp_plot.to_csv("plot_model/disp_plot.csv", index = False)

# %% [markdown]
# ## /a/ reduction across stress

# %%
# data set for plotting
a = df[df["Vowel"]=="a"].copy()
a_stress = a.groupby(["Corpus", "Gender", "stress"])[["F1.50_norm", "F2.50_norm"]].mean()
a_stress = a_stress.reset_index()
a_stress
# Out:
#      Corpus  Gender      stress  F1.50_norm  F2.50_norm
# 0      CBAS  Female    stressed    0.704012    1.445211
# 1      CBAS  Female  unstressed    0.683834    1.438206
# 2      CBAS    Male    stressed    0.659799    1.363305
# 3      CBAS    Male  unstressed    0.633798    1.344531
# 4  DIMEx100  Female    stressed    0.646446    1.536986
# 5  DIMEx100  Female  unstressed    0.620249    1.558152
# 6  DIMEx100    Male    stressed    0.595249    1.528071
# 7  DIMEx100    Male  unstressed    0.584057    1.533586

# %%
# save for plotting
a_stress.to_csv("plot_model/a_stress_plot.csv", index = False)

# %%
# save for model
a.to_csv("plot_model/a_stress_model.csv", index = False)

# %% [markdown]
# ## Consonantal context

# %%
cons_context = df[(df["prev_ph"]=="t") |
                  (df["prev_ph"]=="p") |
                  (df["prev_ph"]=="s")].copy()
len(cons_context)
# Out:
# 1039

# %%
cons_context.groupby(["Corpus", "prev_ph", "Vowel"]).count()
# Out:
#                         Participant  F1.50  F2.50  F3.50  F1.25  F2.25  F3.25  \
# Corpus   prev_ph Vowel
# CBAS     p       a                2      2      2      2      2      2      2
#                  e               13     13     13     13     13     13     13
#                  i                9      9      9      9      9      9      9
#                  o               18     18     18     18     18     18     18
#                  u                5      5      5      5      5      5      5
#          s       a               66     66     66     66     66     66     66
#                  e               80     80     80     80     80     80     80
#                  i               31     31     31     31     31     31     31
#                  o               33     33     33     33     33     33     33
#                  u               10     10     10     10     10     10     10
#          t       a               28     28     28     28     28     28     28
#                  e               74     74     74     74     74     74     74
#                  i                6      6      6      6      6      6      6
#                  o               56     56     56     56     56     56     56
#                  u               17     17     17     17     17     17     17
# DIMEx100 p       a               40     40     40     40     40     40     40
#                  e               22     22     22     22     22     22     22
#                  i                3      3      3      3      3      3      3
#                  o               37     37     37     37     37     37     37
#                  u                5      5      5      5      5      5      5
#          s       a               46     46     46     46     46     46     46
#                  e               86     86     86     86     86     86     86
#                  i               53     53     53     53     53     53     53
#                  o               35     35     35     35     35     35     35
#                  u               30     30     30     30     30     30     30
#          t       a               57     57     57     57     57     57     57
#                  e               59     59     59     59     59     59     59
#                  i               53     53     53     53     53     53     53
#                  o               47     47     47     47     47     47     47
#                  u               18     18     18     18     18     18     18
#
#                         F1.75  F2.75  F3.75  ...  stress  Delta F.50  \
# Corpus   prev_ph Vowel                       ...
# CBAS     p       a          2      2      2  ...       2           2
#                  e         13     13     13  ...      13          13
#                  i          9      9      9  ...       9           9
#                  o         18     18     18  ...      18          18
#                  u          5      5      5  ...       5           5
#          s       a         66     66     66  ...      66          66
#                  e         80     80     80  ...      80          80
#                  i         31     31     31  ...      31          31
#                  o         33     33     33  ...      33          33
#                  u         10     10     10  ...      10          10
#          t       a         28     28     28  ...      28          28
#                  e         74     74     74  ...      74          74
#                  i          6      6      6  ...       6           6
#                  o         56     56     56  ...      56          56
#                  u         17     17     17  ...      17          17
# DIMEx100 p       a         40     40     40  ...      40          40
#                  e         22     22     22  ...      22          22
#                  i          3      3      3  ...       3           3
#                  o         37     37     37  ...      37          37
#                  u          5      5      5  ...       5           5
#          s       a         46     46     46  ...      46          46
#                  e         86     86     86  ...      86          86
#                  i         53     53     53  ...      53          53
#                  o         35     35     35  ...      35          35
#                  u         30     30     30  ...      30          30
#          t       a         57     57     57  ...      57          57
#                  e         59     59     59  ...      59          59
#                  i         53     53     53  ...      53          53
#                  o         47     47     47  ...      47          47
#                  u         18     18     18  ...      18          18
#
#                         Delta F.25  Delta F.75  F1.50_norm  F2.50_norm  \
# Corpus   prev_ph Vowel
# CBAS     p       a               2           2           2           2
#                  e              13          13          13          13
#                  i               9           9           9           9
#                  o              18          18          18          18
#                  u               5           5           5           5
#          s       a              66          66          66          66
#                  e              80          80          80          80
#                  i              31          31          31          31
#                  o              33          33          33          33
#                  u              10          10          10          10
#          t       a              28          28          28          28
#                  e              74          74          74          74
#                  i               6           6           6           6
#                  o              56          56          56          56
#                  u              17          17          17          17
# DIMEx100 p       a              40          40          40          40
#                  e              22          22          22          22
#                  i               3           3           3           3
#                  o              37          37          37          37
#                  u               5           5           5           5
#          s       a              46          46          46          46
#                  e              86          86          86          86
#                  i              53          53          53          53
#                  o              35          35          35          35
#                  u              30          30          30          30
#          t       a              57          57          57          57
#                  e              59          59          59          59
#                  i              53          53          53          53
#                  o              47          47          47          47
#                  u              18          18          18          18
#
#                         F1.25_norm  F2.25_norm  F1.75_norm  F2.75_norm
# Corpus   prev_ph Vowel
# CBAS     p       a               2           2           2           2
#                  e              13          13          13          13
#                  i               9           9           9           9
#                  o              18          18          18          18
#                  u               5           5           5           5
#          s       a              66          66          66          66
#                  e              80          80          80          80
#                  i              31          31          31          31
#                  o              33          33          33          33
#                  u              10          10          10          10
#          t       a              28          28          28          28
#                  e              74          74          74          74
#                  i               6           6           6           6
#                  o              56          56          56          56
#                  u              17          17          17          17
# DIMEx100 p       a              40          40          40          40
#                  e              22          22          22          22
#                  i               3           3           3           3
#                  o              37          37          37          37
#                  u               5           5           5           5
#          s       a              46          46          46          46
#                  e              86          86          86          86
#                  i              53          53          53          53
#                  o              35          35          35          35
#                  u              30          30          30          30
#          t       a              57          57          57          57
#                  e              59          59          59          59
#                  i              53          53          53          53
#                  o              47          47          47          47
#                  u              18          18          18          18
#
# [30 rows x 40 columns]

# %%
cons_context["Dur_ms"] = cons_context["dur_ph"].apply(lambda x: x*1000)
cons_context["Dur_norm"] = cons_context["Dur_ms"] * cons_context["Speech Rate"]
cons_context["Dur_log"] = cons_context["Dur_ms"].apply(lambda x: math.log(x))

# %%
# save for modeling
cons_context.to_csv("plot_model/cons_cont.csv", index = False)

# %%
# for plotting
cons_plot = cons_context.groupby(["Corpus", "Gender", "Vowel", "prev_ph"])[["F1.50_norm", "F2.50_norm", "dur_ph"]].mean()
cons_plot = cons_plot.reset_index()
cons_plot["Dur_ms"] = cons_plot["dur_ph"].apply(lambda x: x*1000)
cons_plot
# Out:
#       Corpus  Gender Vowel prev_ph  F1.50_norm  F2.50_norm    dur_ph  \
# 0       CBAS  Female     a       p    0.636944    1.574071  0.065000
# 1       CBAS  Female     a       s    0.655539    1.403049  0.099048
# 2       CBAS  Female     a       t    0.680445    1.489619  0.141667
# 3       CBAS  Female     e       p    0.501689    1.678223  0.068889
# 4       CBAS  Female     e       s    0.525875    1.555358  0.088269
# 5       CBAS  Female     e       t    0.514525    1.615135  0.099184
# 6       CBAS  Female     i       p    0.324221    1.393843  0.097143
# 7       CBAS  Female     i       s    0.362757    1.859344  0.072857
# 8       CBAS  Female     i       t    0.380081    2.131091  0.090000
# 9       CBAS  Female     o       p    0.478317    0.764494  0.117500
# 10      CBAS  Female     o       s    0.499987    1.060259  0.144545
# 11      CBAS  Female     o       t    0.508575    1.050093  0.130811
# 12      CBAS  Female     u       p    0.345256    0.746963  0.083333
# 13      CBAS  Female     u       s    0.394149    1.126000  0.080000
# 14      CBAS  Female     u       t    0.363059    1.099750  0.106154
# 15      CBAS    Male     a       s    0.625885    1.335438  0.083750
# 16      CBAS    Male     a       t    0.682675    1.463555  0.141000
# 17      CBAS    Male     e       p    0.467762    1.507857  0.060000
# 18      CBAS    Male     e       s    0.494150    1.693254  0.089286
# 19      CBAS    Male     e       t    0.502055    1.714782  0.110400
# 20      CBAS    Male     i       p    0.400696    2.098669  0.100000
# 21      CBAS    Male     i       s    0.421025    2.045028  0.070000
# 22      CBAS    Male     i       t    0.337756    2.042904  0.100000
# 23      CBAS    Male     o       p    0.468924    0.863964  0.100000
# 24      CBAS    Male     o       s    0.430886    0.935624  0.139091
# 25      CBAS    Male     o       t    0.424581    0.982691  0.126316
# 26      CBAS    Male     u       p    0.419642    0.906224  0.075000
# 27      CBAS    Male     u       s    0.378793    0.951820  0.083333
# 28      CBAS    Male     u       t    0.383296    0.984748  0.130000
# 29  DIMEx100  Female     a       p    0.642667    1.484648  0.069968
# 30  DIMEx100  Female     a       s    0.617703    1.525936  0.083833
# 31  DIMEx100  Female     a       t    0.618563    1.551612  0.075568
# 32  DIMEx100  Female     e       p    0.427200    1.717533  0.058556
# 33  DIMEx100  Female     e       s    0.436425    1.706184  0.067288
# 34  DIMEx100  Female     e       t    0.459866    1.774981  0.062923
# 35  DIMEx100  Female     i       p    0.304641    2.130381  0.073000
# 36  DIMEx100  Female     i       s    0.298713    2.128008  0.060159
# 37  DIMEx100  Female     i       t    0.296526    2.133560  0.068000
# 38  DIMEx100  Female     o       p    0.460652    1.096309  0.061500
# 39  DIMEx100  Female     o       s    0.439619    1.242550  0.073000
# 40  DIMEx100  Female     o       t    0.461451    1.248847  0.069968
# 41  DIMEx100  Female     u       p    0.309849    0.831230  0.058000
# 42  DIMEx100  Female     u       s    0.309126    1.132012  0.050435
# 43  DIMEx100  Female     u       t    0.350745    1.169961  0.078833
# 44  DIMEx100    Male     a       p    0.590065    1.355298  0.057333
# 45  DIMEx100    Male     a       s    0.566641    1.502181  0.082000
# 46  DIMEx100    Male     a       t    0.570994    1.543907  0.084538
# 47  DIMEx100    Male     e       p    0.441234    1.654358  0.044000
# 48  DIMEx100    Male     e       s    0.400360    1.781783  0.066815
# 49  DIMEx100    Male     e       t    0.411944    1.794315  0.062350
# 50  DIMEx100    Male     i       p    0.283462    2.002677  0.049000
# 51  DIMEx100    Male     i       s    0.283175    2.070802  0.060000
# 52  DIMEx100    Male     i       t    0.297174    2.162093  0.067818
# 53  DIMEx100    Male     o       p    0.445561    1.043760  0.060333
# 54  DIMEx100    Male     o       s    0.441137    1.146575  0.068375
# 55  DIMEx100    Male     o       t    0.433328    1.179169  0.075688
# 56  DIMEx100    Male     u       p    0.322337    0.850740  0.069667
# 57  DIMEx100    Male     u       s    0.313752    1.234189  0.045143
# 58  DIMEx100    Male     u       t    0.337006    1.248208  0.054500
#
#         Dur_ms
# 0    65.000000
# 1    99.047619
# 2   141.666667
# 3    68.888889
# 4    88.269231
# 5    99.183673
# 6    97.142857
# 7    72.857143
# 8    90.000000
# 9   117.500000
# 10  144.545455
# 11  130.810811
# 12   83.333333
# 13   80.000000
# 14  106.153846
# 15   83.750000
# 16  141.000000
# 17   60.000000
# 18   89.285714
# 19  110.400000
# 20  100.000000
# 21   70.000000
# 22  100.000000
# 23  100.000000
# 24  139.090909
# 25  126.315789
# 26   75.000000
# 27   83.333333
# 28  130.000000
# 29   69.967742
# 30   83.833333
# 31   75.568182
# 32   58.555556
# 33   67.288136
# 34   62.923077
# 35   73.000000
# 36   60.159091
# 37   68.000000
# 38   61.500000
# 39   73.000000
# 40   69.967742
# 41   58.000000
# 42   50.434783
# 43   78.833333
# 44   57.333333
# 45   82.000000
# 46   84.538462
# 47   44.000000
# 48   66.814815
# 49   62.350000
# 50   49.000000
# 51   60.000000
# 52   67.818182
# 53   60.333333
# 54   68.375000
# 55   75.687500
# 56   69.666667
# 57   45.142857
# 58   54.500000

# %%
# save for plotting
cons_plot.to_csv("plot_model/cons_cont_plot.csv", index = False)
