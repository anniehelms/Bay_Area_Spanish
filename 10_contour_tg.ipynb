# %% [markdown]
# # Preparing contour txt files for SS-ANOVA in R

# %% [markdown]
# With a Praat script (Mietta Lennes, 2003), the first three formants were extracted at 2ms intervals within the DIMEx100 and CBAS corpora. The resulting .txt files need to be cleaned and turned into .csv files. To clean, the formant data needs to be merged with the textgrids and vowels need to be isolated. The formant measurements can then be normalized, and then they will be ready to upload to R and fitted with SS-ANOVA.

# %%
import pandas as pd
import os
from audiolabel import read_label

# %% [markdown]
# ### Import formant data
#
# First import DIME data and add new columns for gender and corpus.

# %%
# import dime female
dime_fem_con = pd.read_csv("data/dime_female_contour.txt", sep = "\t")
dime_fem_con = dime_fem_con.rename(columns = {"Filename": "Participant"})
dime_fem_con["Gender"] = "Female"
dime_fem_con["Corpus"] = "DIMEx100"

# import dime male
dime_male_con = pd.read_csv("data/dime_male_contour.txt", sep = "\t")
dime_male_con = dime_male_con.rename(columns = {"Filename": "Participant"})
dime_male_con["Gender"] = "Male"
dime_male_con["Corpus"] = "DIMEx100"

# concatenate male and female data
dime = pd.concat([dime_male_con, dime_fem_con], ignore_index = True)
dime.head()
# Out:
#   Participant phone   Time  Interval                  F1                  F2  \
# 0      s00101     e  0.069     0.002   2094.613890102079   2623.550627119573
# 1      s00101     e  0.071     0.004   2094.042033082855  2624.0054225415506
# 2      s00101     e  0.073     0.006   2093.470176063631  2624.4602179635285
# 3      s00101     e  0.075     0.008  2092.8983190444064   2624.915013385506
# 4      s00101     e  0.077     0.010   2092.326462025182  2625.3698088074834
#
#                   F3  Gender    Corpus
# 0  3466.0182725549303   Male  DIMEx100
# 1  3465.6262512556896   Male  DIMEx100
# 2  3465.2342299564493   Male  DIMEx100
# 3   3464.842208657209   Male  DIMEx100
# 4   3464.450187357969   Male  DIMEx100

# %% [markdown]
# Now do the same with the CBAS corpus.

# %%
# import cbas female
cbas_fem = pd.read_csv("data/cbas_female_contour.txt", sep = "\t")
cbas_fem = cbas_fem.rename(columns = {"Filename": "Participant"})
cbas_fem["Gender"] = "Female"
cbas_fem["Corpus"] = "CBAS"

# import cbas male
cbas_male = pd.read_csv("data/cbas_male_contour.txt", sep = "\t")
cbas_male = cbas_male.rename(columns = {"Filename": "Participant"})
cbas_male["Gender"] = "Male"
cbas_male["Corpus"] = "CBAS"

# combine cbas female and male
cbas = pd.concat([cbas_male, cbas_fem], ignore_index = True)
cbas.head()
# Out:
#   Participant Segment label        F1.50        F2.50        F3.50  \
# 0        p112           sil  1349.549295  2591.478429  3249.782912
# 1        p112             b   538.241047  1256.248187  2799.236009
# 2        p112             a   695.790976  1139.953282  2667.258621
# 3        p112             x   751.966861  1524.518652  2973.220585
# 4        p112             o   423.620505   737.502557  2374.974921
#
#          F1.25        F2.25        F3.25       F1.75        F2.75  \
# 0  1640.246420  2418.644376  3493.133471  703.933103  2157.879849
# 1   884.928365  2273.697186  3419.016247  203.380184   972.145970
# 2   689.324612   840.183174  2738.685252  672.665361  1108.588353
# 3   702.809393  1206.953717  2902.094060  765.207925  1004.810302
# 4   438.929950   803.823366  2369.001274  442.314537   785.356913
#
#          F3.75 Gender Corpus
# 0  2892.455533   Male   CBAS
# 1  2675.148493   Male   CBAS
# 2  2626.355793   Male   CBAS
# 3  2809.626524   Male   CBAS
# 4  2490.718660   Male   CBAS

# %% [markdown]
# Now concatenate the cbas and dime dataframes.

# %%
# combine cbas and dime
formants = pd.concat([cbas, dime], ignore_index = True)
formants.head()
# Out:
#   Participant Segment label        F1.50        F2.50        F3.50  \
# 0        p112           sil  1349.549295  2591.478429  3249.782912
# 1        p112             b   538.241047  1256.248187  2799.236009
# 2        p112             a   695.790976  1139.953282  2667.258621
# 3        p112             x   751.966861  1524.518652  2973.220585
# 4        p112             o   423.620505   737.502557  2374.974921
#
#          F1.25        F2.25        F3.25       F1.75        F2.75  \
# 0  1640.246420  2418.644376  3493.133471  703.933103  2157.879849
# 1   884.928365  2273.697186  3419.016247  203.380184   972.145970
# 2   689.324612   840.183174  2738.685252  672.665361  1108.588353
# 3   702.809393  1206.953717  2902.094060  765.207925  1004.810302
# 4   438.929950   803.823366  2369.001274  442.314537   785.356913
#
#          F3.75 Gender Corpus phone  Time  Interval   F1   F2  F3   t1_ph
# 0  2892.455533   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 1  2675.148493   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 2  2626.355793   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 3  2809.626524   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 4  2490.718660   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN

# %% [markdown]
# In order to later merge with the associated TextGrids, create a new column called `t1_ph` that contains the timestamp of the interval start.

# %%
dime["t1_ph"] = dime["Time"]-dime["Interval"]
dime.head()
# Out:
#   Participant Segment label        F1.50        F2.50        F3.50  \
# 0        p112           sil  1349.549295  2591.478429  3249.782912
# 1        p112             b   538.241047  1256.248187  2799.236009
# 2        p112             a   695.790976  1139.953282  2667.258621
# 3        p112             x   751.966861  1524.518652  2973.220585
# 4        p112             o   423.620505   737.502557  2374.974921
#
#          F1.25        F2.25        F3.25       F1.75        F2.75  \
# 0  1640.246420  2418.644376  3493.133471  703.933103  2157.879849
# 1   884.928365  2273.697186  3419.016247  203.380184   972.145970
# 2   689.324612   840.183174  2738.685252  672.665361  1108.588353
# 3   702.809393  1206.953717  2902.094060  765.207925  1004.810302
# 4   438.929950   803.823366  2369.001274  442.314537   785.356913
#
#          F3.75 Gender Corpus phone  Time  Interval   F1   F2  F3   t1_ph
# 0  2892.455533   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 1  2675.148493   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 2  2626.355793   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 3  2809.626524   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN
# 4  2490.718660   Male   CBAS   NaN   NaN       NaN  NaN  NaN  NaN    NaN

# %% [markdown]
# ### Import TextGrids

# %%
cbasdf = pd.DataFrame({
    'relpath': 'textgrids/cbas',
    'fname': ['p112.TextGrid',
              'p119.TextGrid',
              'p113.TextGrid',
              'p115.TextGrid',
              'p120.TextGrid',
              'p124.TextGrid'],
    'subject': ['p112', 'p119', 'p113', 'p115', 'p120', 'p124']
})

dimedf = pd.DataFrame({
    'relpath': 'textgrids/dime',
    'fname' : os.listdir("textgrids/dime")})
dimedf['subject'] = dimedf['fname'].apply(lambda x: x[:6])

tgdf = pd.concat([cbasdf, dimedf], ignore_index = True)

# %%
# inputs 

def tg2df(row):
    '''Load 'phone' and 'word' tiers from a textgrid and merge them.
    
    Parameters
    ----------
    
    row: named tuple
    A namedtuple as provided by `itertuples` that can be used to load a Praat
    textgrid from a path identified by row.relpath and row.fname. The textgrid is
    expected to have 'phone' and 'word' tiers.

    Returns
    -------
    
    mergedf: the merged dataframe.
    '''
    [wddf, phdf] = read_label(
        os.path.join(row.relpath, row.fname).replace("\\","/"),
        ftype='praat',
        tiers=['word', 'phone']
    )
    # Throw an error if tiers are not strictly hierarchical.
    # words contain phones
    assert(wddf.t1.isin(phdf.t1).all())
    assert(wddf.t2.isin(phdf.t2).all())
    
    # Add phone duration and speaker
    phdf['dur_ph'] = phdf.t2 - phdf.t1
    phdf['Participant'] = row.subject

    # Merge phone and word tiers.
    phwddf = pd.merge_asof(
        phdf.rename({'t1': 't1_ph', 't2': 't2_ph'}, axis='columns'),
        wddf.drop('fname', axis='columns') \
            .rename({'t1': 't1_wd', 't2': 't2_wd'}, axis='columns'),
        left_on='t1_ph',
        right_on='t1_wd'
    )

    # Add word-init and -final columns
    phwddf['is_wdinit_ph'] = phwddf.t1_ph == phwddf.t1_wd
    phwddf['is_wdfin_ph'] = phwddf.t2_ph == phwddf.t2_wd

    # Merge context tier and return the result.
    return phwddf

# %%
dflist = [tg2df(row) for row in tgdf.itertuples()]

# %%
alldf = pd.concat(dflist, ignore_index=True)

alldf.sample(10)
# Out:
#          t1_ph       t2_ph phone                           fname    dur_ph  \
# 509    143.148  143.248000     m    textgrids/cbas/p112.TextGrid  0.100000
# 13038    1.064    1.112000     e  textgrids/dime/s05132.TextGrid  0.048000
# 2965   241.200  241.440000    ng    textgrids/cbas/p113.TextGrid  0.240000
# 19158    0.598    0.671000     n  textgrids/dime/s05538.TextGrid  0.073000
# 9602     3.158    3.161088        textgrids/dime/s00219.TextGrid  0.003088
# 6638     2.856    2.955000     m  textgrids/dime/s00103.TextGrid  0.099000
# 10893    0.181    0.221000     e  textgrids/dime/s00245.TextGrid  0.040000
# 11168    1.715    1.740000     i  textgrids/dime/s00250.TextGrid  0.025000
# 5916   198.451  200.028000    sp    textgrids/cbas/p124.TextGrid  1.577000
# 11729    2.233    2.303000     n  textgrids/dime/s05110.TextGrid  0.070000
#
#       Participant    t1_wd       t2_wd              word  is_wdinit_ph  \
# 509          p112  142.548  143.378000        vandalismo         False
# 13038      s05132    1.020    1.112000                de         False
# 2965         p113  240.330  241.440000              bien         False
# 19158      s05538    0.531    0.739000               una         False
# 9602       s00219    3.158    3.161088                            True
# 6638       s00103    2.784    3.544000        importante         False
# 10893      s00245    0.181    0.712000       evolucio_7n          True
# 11168      s00250    1.210    1.862000    construccio_7n         False
# 5916         p124  198.451  200.028000                            True
# 11729      s05110    1.497    2.303000  administracio_7n         False
#
#        is_wdfin_ph
# 509          False
# 13038         True
# 2965          True
# 19158        False
# 9602          True
# 6638         False
# 10893        False
# 11168        False
# 5916          True
# 11729         True

# %% [markdown]
# Create cols `prev_ph` and `next_ph` containing previous and following phones.

# %%
alldf['prev_ph'] = alldf.phone.shift(1).fillna('')
alldf['next_ph'] = alldf.phone.shift(-1).fillna('')
alldf = alldf[alldf["phone"]!=""]
alldf = alldf.reset_index(drop = True)

# %%
alldf
# Out:
#        t1_ph  t2_ph phone                           fname  dur_ph Participant  \
# 0      0.000  0.710   sil    textgrids/cbas/p112.TextGrid   0.710        p112
# 1      0.710  0.820     b    textgrids/cbas/p112.TextGrid   0.110        p112
# 2      0.820  0.920     a    textgrids/cbas/p112.TextGrid   0.100        p112
# 3      0.920  1.000     x    textgrids/cbas/p112.TextGrid   0.080        p112
# 4      1.000  1.140     o    textgrids/cbas/p112.TextGrid   0.140        p112
# ...      ...    ...   ...                             ...     ...         ...
# 22107  5.368  5.432     k  textgrids/dime/s05650.TextGrid   0.064      s05650
# 22108  5.432  5.525     t  textgrids/dime/s05650.TextGrid   0.093      s05650
# 22109  5.525  5.584     o  textgrids/dime/s05650.TextGrid   0.059      s05650
# 22110  5.584  5.622    r(  textgrids/dime/s05650.TextGrid   0.038      s05650
# 22111  5.622  5.781  .sil  textgrids/dime/s05650.TextGrid   0.159      s05650
#
#        t1_wd  t2_wd    word  is_wdinit_ph  is_wdfin_ph prev_ph next_ph
# 0      0.000  0.710                  True         True               b
# 1      0.710  1.140    bajo          True        False     sil       a
# 2      0.710  1.140    bajo         False        False       b       x
# 3      0.710  1.140    bajo         False        False       a       o
# 4      0.710  1.140    bajo         False         True       x      sp
# ...      ...    ...     ...           ...          ...     ...     ...
# 22107  5.185  5.622  sector         False        False       e       t
# 22108  5.185  5.622  sector         False        False       k       o
# 22109  5.185  5.622  sector         False        False       t      r(
# 22110  5.185  5.622  sector         False         True       o    .sil
# 22111  5.622  5.781    .sil          True         True      r(
#
# [22112 rows x 13 columns]

# %% [markdown]
# ### Merge formant and TextGrid data

# %%
# later change dime to formants
data = dime.merge(alldf, how='left', left_on=['Participant','t1_ph'], right_on = ['Participant','t1_ph'])
data = data.drop(["phone_y"], axis = 1)
data = data.rename(columns = {"phone_x": "phone"})
data.head()
# Out:
#   Participant phone   Time  Interval                  F1                  F2  \
# 0      s00101     e  0.069     0.002   2094.613890102079   2623.550627119573
# 1      s00101     e  0.071     0.004   2094.042033082855  2624.0054225415506
# 2      s00101     e  0.073     0.006   2093.470176063631  2624.4602179635285
# 3      s00101     e  0.075     0.008  2092.8983190444064   2624.915013385506
# 4      s00101     e  0.077     0.010   2092.326462025182  2625.3698088074834
#
#                   F3  Gender    Corpus  t1_ph  t2_ph  \
# 0  3466.0182725549303   Male  DIMEx100  0.067   0.15
# 1  3465.6262512556896   Male  DIMEx100  0.067   0.15
# 2  3465.2342299564493   Male  DIMEx100  0.067   0.15
# 3   3464.842208657209   Male  DIMEx100  0.067   0.15
# 4   3464.450187357969   Male  DIMEx100  0.067   0.15
#
#                             fname  dur_ph  t1_wd  t2_wd word is_wdinit_ph  \
# 0  textgrids/dime/s00101.TextGrid   0.083  0.067  0.215   en         True
# 1  textgrids/dime/s00101.TextGrid   0.083  0.067  0.215   en         True
# 2  textgrids/dime/s00101.TextGrid   0.083  0.067  0.215   en         True
# 3  textgrids/dime/s00101.TextGrid   0.083  0.067  0.215   en         True
# 4  textgrids/dime/s00101.TextGrid   0.083  0.067  0.215   en         True
#
#   is_wdfin_ph prev_ph next_ph
# 0       False               n
# 1       False               n
# 2       False               n
# 3       False               n
# 4       False               n

# %% [markdown]
# Now to fix errors/inconsistencies:

# %%
# run this cell when I don't have cbas data yet
data = data.dropna()
data = data.reset_index(drop=True)

# %%
import re

# fix phones from txt file, remove + following some vowels
data["phone"] = data["phone"].apply(lambda x: re.sub("([aeiou])\+", "\1", x))

# replace `r(` with `rf` for consistency
data['word'] = data['word'].apply(lambda x: re.sub("r\(", "rf", x))

# fix notation in dimex corpus, where V_7 yields accented V
data['word'] = data['word'].apply(lambda x: re.sub("a_7", "á", x))
data['word'] = data['word'].apply(lambda x: re.sub("i_7", "í", x))
data['word'] = data['word'].apply(lambda x: re.sub("o_7", "ó", x))
data['word'] = data['word'].apply(lambda x: re.sub("u_7", "ú", x))
data['word'] = data['word'].apply(lambda x: re.sub("e_7", "é", x))

# fix tildas
data['word'] = data['word'].apply(lambda x: re.sub("n~", "ñ", x))

# remove phones `sp` and `.sil`
data = data[(data['phone'] != ".sil") & (data['phone'] != "sp")]

data = data.reset_index(drop = True)

# %% [markdown]
# Now that we have made use of the Participant naming system in DIMEx to combine the tg and formant data, we can rename the Participant column, dropping the indication of the task number.

# %%
# fix naming of participant col
data["Participant"] = data["Participant"].apply(lambda x: x[:4])

# %% [markdown]
# Now to isolate the vowels.

# %%
# remove rows not containing vowels
vowelsdf = data[(data['phone']=="a") | 
                 (data['phone']=="e") | 
                 (data['phone']=="i") | 
                 (data['phone']=="u") | 
                 (data['phone']=="o")]
vowelsdf = vowelsdf.reset_index(drop = True)
vowelsdf = vowelsdf.rename(columns = {"phone": "Vowel"})
len(vowelsdf)
# Out:
# 114773

# %% [markdown]
# ### Speech rate
#
# First we will take the number of vowels a speaker produces to be equal to the number of syllables they utter. Then we will take the unique values from the `t1_wd` and `t2_wd` columns and subtract t2 from t1 to obtain an array of the duration of each word uttered. Then we will sum the durations of all words and divide the number of syllables by this value.

# %%
def speech_rate(df):
    import numpy as np

    Participant = []
    speech_rate = []

    for i in df.Participant.unique():
        data = df[df["Participant"]==i]
        syllables = len(data.Vowel)
        end_times = data["t2_wd"]
        start_times = data["t1_wd"]
        durations = np.subtract(end_times, start_times)
        duration = sum(durations)
        rate = syllables/duration
    
        Participant.append(i)
        speech_rate.append(rate)

    rates = {k:v for k,v in zip(Participant, speech_rate)}
    rates_df = pd.DataFrame.from_dict(rates, orient = "index", columns = ['Speech Rate'])
    rates_df = rates_df.rename_axis('Participant').reset_index()
    
    df = pd.merge(left = df, right = rates_df, on = 'Participant', how = 'outer')
    return df

# %%
vowelsdf = speech_rate(vowelsdf)

# %% [markdown]
# ### Stress
#
# The syltippy package (https://github.com/nur-ag/syltippy) will be used to generate syllabified (stress-indicated) outputs for each word found in the transcriptions. Then, the corresponding vowels in the TextGrid-formant dataframes will be marked as either stressed or unstressed.

# %%
# function takes into dictionary.txt file with cols `word` and `ipa`
# input formants df with cols `Participant`, `word`, `t1_wd`, and `t1_ph`

def get_stress(vowels):
    # import required packages
    import csv
    import numpy as np
    from syltippy import syllabize
    
    # def fxn to create stress column in dictionary
    def stress(word):
        syllables, stress = syllabize(word)
        return ','.join(s if stress != i else s.upper() for (i, s) in enumerate(syllables))
    
    # add column to dictionary
    vowels["stress_syll"] = vowels["word"].apply(lambda x : stress(str(x)))
    
    # create separate column to hold only the vowels in each word
    vowels["syll_vowels"] = vowels["stress_syll"].apply(lambda x: re.sub(r'[^,aeiouAEIOUáéíóúÁÉÍÓÚ]', '', x))
    
    # define function to return index of 'vowels' column with stress
    def is_stress(word):
        # convert to list
        word = word.split(",")
        stress_vowel = 0
        for syllable in word:
            if syllable.isupper():
                stress_vowel = word.index(syllable)
        return stress_vowel
    
    # create new column which gives vowel number in given word that has stress
    vowels["stress_vowel"] = vowels["syll_vowels"].apply(lambda x: is_stress(x))
    
    # determine index of vowel in df
    vowels["vowel_ind"] = vowels.groupby(["fname", "t1_wd"])["t1_ph"].apply(lambda x:x.astype('category').cat.codes).astype(int)

    #vowels = vowels.reset_index(drop = True)
    
    # add column to formants to indicate stress
    vowels["stress"] = np.where(vowels['stress_vowel'] == vowels['vowel_ind'], "stressed", "unstressed")
    
    # drop unnecesary columns
    vowels = vowels.drop(["syll_vowels", "stress_syll"], axis = 1)
       
    return vowels

# %%
vowelsdf = get_stress(vowelsdf)

# %%
vowelsdf.sample(50)
# Out:
#        Participant Vowel   Time  Interval                  F1  \
# 78357         s055     u  5.034     0.018  401.99053185632545
# 34646         s051     a  2.890     0.068   535.0795242177925
# 45109         s051     e  0.426     0.048  368.93239561022847
# 14116         s001     a  0.154     0.094   570.6473545159527
# 89502         s055     e  1.399     0.076  441.71344797586585
# 6321          s001     a  0.644     0.024   422.0363441101842
# 108012        s056     e  2.219     0.076   571.6697728197019
# 912           s001     e  1.929     0.018    396.005735015644
# 90896         s055     o  0.551     0.074   534.2424633075324
# 31679         s002     e  1.338     0.020  456.90434289023136
# 46718         s051     a  2.101     0.088   696.4470281302948
# 30101         s002     a  4.756     0.032   775.8930850372751
# 10147         s001     a  1.595     0.054   441.7340654625276
# 114208        s056     a  0.554     0.078   1096.823255590488
# 101641        s056     u  1.554     0.044  411.27323771800275
# 25151         s002     e  2.499     0.076   282.7791857122701
# 37024         s051     a  3.780     0.010   720.8832520536973
# 7859          s001     u  2.452     0.090  292.35441109639527
# 13392         s001     a  0.405     0.024    548.434174119645
# 85379         s055     e  2.364     0.040   574.4793236067968
# 76431         s055     o  2.319     0.016   566.6445169717337
# 71032         s055     e  1.082     0.012   553.1495730168585
# 44410         s051     e  1.165     0.024  488.18128733097547
# 82370         s055     e  2.667     0.002   459.6723801448228
# 21492         s002     e  0.324     0.006   458.1635970382156
# 17017         s002     o  1.568     0.024   447.3214174481251
# 87730         s055     e  4.596     0.018  492.77883204212606
# 16545         s002     i  2.177     0.070  358.83223935485677
# 100393        s056     e  0.081     0.012    682.927765850559
# 80345         s055     u  0.851     0.004   423.8039979152504
# 38959         s051     o  1.694     0.024   582.5415704060092
# 12593         s001     e  2.846     0.064  359.34447816813685
# 81997         s055     a  4.881     0.046   565.1344956406734
# 38585         s051     e  3.935     0.032   574.9146482833332
# 96960         s056     o  1.973     0.052  449.50821907297944
# 90022         s055     o  0.539     0.052   736.0976167090727
# 11346         s001     e  1.956     0.016   467.8096261279831
# 25519         s002     e  0.710     0.028   449.4283030762443
# 48689         s051     a  0.639     0.006   742.8183799779257
# 39360         s051     e  0.863     0.052   582.0917440771219
# 55035         s053     a  1.429     0.042   840.2825414621127
# 61001         s053     a  1.893     0.040   610.5808983361391
# 20628         s002     o  1.125     0.056   410.7622745241714
# 77924         s055     o  0.061     0.010   665.1456155979773
# 92365         s055     o  1.268     0.060  415.91776853732205
# 80018         s055     o  3.842     0.044   497.4864666402573
# 37448         s051     a  1.409     0.026     752.46306744099
# 65834         s053     a  1.778     0.008  441.82122304964815
# 21766         s002     a  2.066     0.094    751.963009883144
# 61503         s053     a  0.822     0.022   689.7807590015596
#
#                         F2                 F3   Gender    Corpus  t1_ph  ...  \
# 78357   1276.4251934028937  2834.8470770107997  Female  DIMEx100  5.016  ...
# 34646   1863.8628669339164   2416.691567061131  Female  DIMEx100  2.822  ...
# 45109   2248.1457817369824  3164.2137874078544  Female  DIMEx100  0.378  ...
# 14116   1568.7787055395484  2450.3417166173817    Male  DIMEx100  0.060  ...
# 89502   2028.9561367920978  3098.2580011859527  Female  DIMEx100  1.323  ...
# 6321    1578.2845350090354   2371.064662461464    Male  DIMEx100  0.620  ...
# 108012   2464.222552121423  3349.6053520025544  Female  DIMEx100  2.143  ...
# 912      1686.958087757669    2595.91793717752    Male  DIMEx100  1.911  ...
# 90896   1662.0408008990628  3076.7893289401927  Female  DIMEx100  0.477  ...
# 31679    1832.825697020567  2912.1275134003126    Male  DIMEx100  1.318  ...
# 46718   1761.0343577101157  1959.5962613606193  Female  DIMEx100  2.013  ...
# 30101   1557.7910203926594  2927.0574490496037    Male  DIMEx100  4.724  ...
# 10147    1584.557234674916   2399.781033064829    Male  DIMEx100  1.541  ...
# 114208   2001.857650119711  2539.5147757209284  Female  DIMEx100  0.476  ...
# 101641  1236.7131869225677  3087.7376708312595  Female  DIMEx100  1.510  ...
# 25151   1655.1913597818923  2733.2060160489873    Male  DIMEx100  2.423  ...
# 37024   1809.2950556523576   2530.409247842586  Female  DIMEx100  3.770  ...
# 7859      1123.73375189492   2640.684119044959    Male  DIMEx100  2.362  ...
# 13392   1433.5938670301762  2565.3981503784685    Male  DIMEx100  0.381  ...
# 85379   1567.5842371086053  1969.2016260436783  Female  DIMEx100  2.324  ...
# 76431   1213.0350830666653   2538.720974139951  Female  DIMEx100  2.303  ...
# 71032   1862.6319219054951   2929.163039515975  Female  DIMEx100  1.070  ...
# 44410    2084.355163664403   2815.642963643967  Female  DIMEx100  1.141  ...
# 82370   1721.1712883110208   2291.587766688597  Female  DIMEx100  2.665  ...
# 21492     1706.16982156141  2356.5916223411778    Male  DIMEx100  0.318  ...
# 17017   1137.9541411310129  2694.2394785383826    Male  DIMEx100  1.544  ...
# 87730    2305.033888148105    2976.64006201353  Female  DIMEx100  4.578  ...
# 16545   1992.4664686112076  2862.8954667176995    Male  DIMEx100  2.107  ...
# 100393  2253.0918935440627   3237.646444264221  Female  DIMEx100  0.069  ...
# 80345   1376.6693749733338   3086.510418681076  Female  DIMEx100  0.847  ...
# 38959   1591.0025881613606   2974.469375771948  Female  DIMEx100  1.670  ...
# 12593   1919.7853706400174  2315.2413457114317    Male  DIMEx100  2.782  ...
# 81997   1831.3226025536485   3029.265056175174  Female  DIMEx100  4.835  ...
# 38585   1605.9630879737072  2858.4762052028486  Female  DIMEx100  3.903  ...
# 96960   1297.6684389805794     2506.1067322338  Female  DIMEx100  1.921  ...
# 90022   1628.0646356836544  3393.5579455172506  Female  DIMEx100  0.487  ...
# 11346   1766.6327835901332  2563.0478926458627    Male  DIMEx100  1.940  ...
# 25519   2249.0970318867103   2794.628457540157    Male  DIMEx100  0.682  ...
# 48689   1893.2493813313467   3167.587338029104  Female  DIMEx100  0.633  ...
# 39360   1976.9759384174665   2553.810205103873  Female  DIMEx100  0.811  ...
# 55035   1875.2636971895522  3305.4050159463786  Female  DIMEx100  1.387  ...
# 61001   1734.8479729775972  3098.3362846934447  Female  DIMEx100  1.853  ...
# 20628    889.4972554000058  2691.8488629941676    Male  DIMEx100  1.069  ...
# 77924    1246.465689706831  2655.6649117318084  Female  DIMEx100  0.051  ...
# 92365   1512.3637149484118   2971.694641491516  Female  DIMEx100  1.208  ...
# 80018   1480.8894975478722   3006.465780553748  Female  DIMEx100  3.798  ...
# 37448   1440.1817712818013  2209.6083851495277  Female  DIMEx100  1.383  ...
# 65834   1793.5310000499624   3037.592712969951  Female  DIMEx100  1.770  ...
# 21766   1702.8622733069412   2689.619399836488    Male  DIMEx100  1.972  ...
# 61503   1791.3278849168971   2534.685365561603  Female  DIMEx100  0.800  ...
#
#         t2_wd             word  is_wdinit_ph  is_wdfin_ph  prev_ph next_ph  \
# 78357   5.141       curriculum         False        False        l       m
# 34646   3.179        salamanca         False        False        m       n
# 45109   0.652        elementos         False        False        m       n
# 14116   0.537          adriano          True        False                d
# 89502   1.490               en          True        False       r(       n
# 6321    0.954     organización         False        False        s       s
# 108012  2.285    adecuadamente         False         True        t    .sil
# 912     1.961               de         False         True        d       m
# 90896   0.624         pioneros         False        False       r(       s
# 31679   1.961        educación          True        False        l       d
# 46718   2.258             imán         False        False        m       n
# 30101   4.829           óptima         False         True        m    .sil
# 10147   1.595               la         False         True        l       l
# 114208  0.699           además         False        False        m       s
# 101641  1.955          fundada         False        False        f       n
# 25151   2.504               se         False         True        s       l
# 37024   3.830           contra         False         True       r(       l
# 7859    2.606          actitud         False        False        t       d
# 13392   1.088      humanidades         False        False        m       n
# 85379   2.440               el          True        False       r(       l
# 76431   2.746       reportaron         False        False        p      r(
# 71032   1.138               de         False         True        d       b
# 44410   1.925   universitarios         False        False        b      r(
# 82370   2.741               de         False         True        d       s
# 21492   0.813         reconoce         False        False        r       k
# 17017   1.716            autor         False        False        t      r(
# 87730   4.927          mediana         False        False        m       d
# 16545   2.548      comunidades         False        False        n       d
# 100393  0.203               en          True        False                n
# 80345   1.124         estudios         False        False        t       d
# 38959   1.735           ámbito         False         True        t       t
# 12593   3.169  correspondencia         False        False        d       n
# 81997   4.921             para         False         True       r(       s
# 38585   3.985               en          True        False        s       n
# 96960   2.339        doctorado         False        False        t      r(
# 90022   0.558            acaso         False         True        s       n
# 11346   2.327        diferente         False        False       r(       n
# 25519   0.730            tiene         False         True        n       k
# 48689   0.717          empresa         False         True        s       f
# 39360   0.866               de         False         True        d       l
# 55035   1.764        distancia         False        False        t       n
# 61001   2.575       asistencia          True        False        d       s
# 20628   1.310         pedagogo         False        False        g       g
# 77924   0.321             otro          True        False                t
# 92365   1.702       protección         False        False       r(       t
# 80018   4.000               .0         False        False        t       d
# 37448   1.649          reparto         False        False        p      r(
# 65834   2.142     personalizar         False        False        n       l
# 21766   2.085          empresa         False         True        s    .sil
# 61503   0.870             para         False         True       r(       b
#
#        Speech Rate stress_vowel vowel_ind      stress
# 78357     1.893287            3         3    stressed
# 34646     2.114681            2         2    stressed
# 45109     2.114681            2         2    stressed
# 14116     2.167846            1         0  unstressed
# 89502     1.893287            0         0    stressed
# 6321      2.167846            4         2  unstressed
# 108012    1.923002            4         3  unstressed
# 912       2.167846            0         0    stressed
# 90896     1.893287            1         1    stressed
# 31679     2.270729            3         0  unstressed
# 46718     2.114681            1         1    stressed
# 30101     2.270729            0         1  unstressed
# 10147     2.167846            0         0    stressed
# 114208    1.923002            2         2    stressed
# 101641    1.923002            1         0  unstressed
# 25151     2.270729            0         0    stressed
# 37024     2.114681            0         1  unstressed
# 7859      2.167846            2         1  unstressed
# 13392     2.167846            3         1  unstressed
# 85379     1.893287            0         0    stressed
# 76431     1.893287            2         1  unstressed
# 71032     1.893287            0         0    stressed
# 44410     2.114681            4         2  unstressed
# 82370     1.893287            0         0    stressed
# 21492     2.270729            2         0  unstressed
# 17017     2.270729            1         0  unstressed
# 87730     1.893287            1         0  unstressed
# 16545     2.270729            3         2  unstressed
# 100393    1.923002            0         0    stressed
# 80345     1.893287            1         0  unstressed
# 38959     2.114681            0         2  unstressed
# 12593     2.167846            3         2  unstressed
# 81997     1.893287            0         1  unstressed
# 38585     2.114681            0         0    stressed
# 96960     1.923002            2         1  unstressed
# 90022     1.893287            1         2  unstressed
# 11346     2.167846            2         2    stressed
# 25519     2.270729            0         0    stressed
# 48689     2.114681            1         1    stressed
# 39360     2.114681            0         0    stressed
# 55035     2.113555            1         1    stressed
# 61001     2.113555            2         0  unstressed
# 20628     2.270729            2         2    stressed
# 77924     1.893287            0         0    stressed
# 92365     1.893287            2         0  unstressed
# 80018     1.893287            0         1  unstressed
# 37448     2.114681            1         1    stressed
# 65834     2.113555            4         2  unstressed
# 21766     2.270729            1         1    stressed
# 61503     2.113555            0         1  unstressed
#
# [50 rows x 24 columns]

# %% [markdown]
# ### Normalization of vowel formants
#
# Because both male and female speakers are represented in this data set, the formant frequencies need to be normalized to minimized vocal tract length differences.
#
# Following Johnson (2018), I will use the line-fitting Delta F Normalization method, which makes use of the entire vowel space. To do so, the average vowel space will be calculated for each participant, and then each F1 and F2 measurement will be divided by this value.
#
# First we will calculate the average formant measurements over each vowel production, to get an estimate of the 'midpoint'.

# %%
vowelsdf["F1"] = vowelsdf["F1"].astype(float)
vowelsdf["F2"] = vowelsdf["F2"].astype(float)
vowelsdf["F3 "] = vowelsdf["F3 "].astype(float)
vowelsdf = vowelsdf.rename(columns={"F3 ": "F3"})

# %%
import numpy as np

def delta_f(vowels): # df as argument
    
    Participant = []
    ll = []
    
    for i in vowels.Participant.unique():
        data = vowels[vowels['Participant']==i]
        
        delta = np.mean([np.true_divide(data["F1"], 0.5), 
                        np.true_divide(data["F2"], 1.5), 
                        np.true_divide(data["F3"], 2.5)
                       ])
        
        Participant.append(i)
        ll.append(delta)
    
    deltas = {k:v for k,v in zip(Participant, ll)}
    delta_df = pd.DataFrame.from_dict(deltas, orient = "index", columns = ['Delta F'])
    delta_df = delta_df.rename_axis('Participant').reset_index()
        
    return(delta_df)

# %%
def normalization(vowels):
    delta_df = delta_f(vowels)
    
    deltas = delta_df.set_index("Participant")
    deltas = deltas.reset_index()
    
    vowels_normalized = pd.merge(left = vowels,
                                 right = deltas,
                                 on = 'Participant',
                                 how = 'outer')
    vowels_normalized['F1_norm'] = vowels_normalized['F1']/vowels_normalized['Delta F']
    vowels_normalized['F2_norm'] = vowels_normalized['F2']/vowels_normalized['Delta F']
    
    return(vowels_normalized)

# %%
vowels_norm = normalization(vowelsdf)
print(len(vowels_norm))
vowels_norm.sample(10)
# Out:
# 114773
#        Participant Vowel   Time  Interval          F1           F2  \
# 32343         s051     a  0.280     0.020  823.513739  1845.030799
# 113440        s056     e  2.150     0.044  509.241245  1945.738349
# 22421         s002     e  0.114     0.036  446.710276  2044.109721
# 106256        s056     e  0.831     0.020  582.809665  1889.659100
# 74657         s055     u  2.915     0.032  403.890779  1603.536598
# 100722        s056     a  3.360     0.010  414.576179  2095.726196
# 64597         s053     e  0.275     0.036  488.161468  1941.556191
# 44411         s051     e  1.167     0.026  498.589669  2083.421502
# 30108         s002     a  4.772     0.048  981.191064  1556.047274
# 113160        s056     a  2.657     0.008  471.192532   688.771064
#
#                  F3  Gender    Corpus  t1_ph  ...  prev_ph next_ph  \
# 32343   1971.334897  Female  DIMEx100  0.260  ...       r(       f
# 113440  2943.770344  Female  DIMEx100  2.106  ...        d       b
# 22421   2868.952192    Male  DIMEx100  0.078  ...                Z
# 106256  3031.555921  Female  DIMEx100  0.811  ...        d       l
# 74657   2788.974967  Female  DIMEx100  2.883  ...       r(       s
# 100722  3118.557632  Female  DIMEx100  3.350  ...        k       s
# 64597   2986.323601  Female  DIMEx100  0.239  ...        m      r(
# 44411   2828.720917  Female  DIMEx100  1.141  ...        b      r(
# 30108   2832.002903    Male  DIMEx100  4.724  ...        m    .sil
# 113160  2142.094124  Female  DIMEx100  2.649  ...       r(       l
#
#         Speech Rate  stress_vowel  vowel_ind      stress      F1_mid  \
# 32343      2.114681             0          1  unstressed  857.442640
# 113440     1.923002             0          0    stressed  514.409162
# 22421      2.270729             0          0    stressed  418.106052
# 106256     1.923002             0          0    stressed  554.846485
# 74657      1.893287             0          1  unstressed  341.875626
# 100722     1.923002             4          3  unstressed  476.000243
# 64597      2.113555             0          1  unstressed  456.534262
# 44411      2.114681             4          2  unstressed  477.855254
# 30108      2.270729             0          1  unstressed  894.684223
# 113160     1.923002             2          2    stressed  682.326833
#
#             Delta F   F1_norm   F2_norm
# 32343   1148.993852  0.716726  1.605780
# 113440  1155.803643  0.440595  1.683451
# 22421   1048.729308  0.425954  1.949130
# 106256  1155.803643  0.504246  1.634931
# 74657   1157.700870  0.348873  1.385104
# 100722  1155.803643  0.358691  1.813220
# 64597   1152.303798  0.423640  1.684934
# 44411   1148.993852  0.433936  1.813257
# 30108   1048.729308  0.935600  1.483745
# 113160  1155.803643  0.407675  0.595924
#
# [10 rows x 28 columns]

# %% [markdown]
# For SS-ANOVA, duration of each vowel needs to be scaled from 0 to 1. To do this, create a new column `RTime` that is the result of `Interval` divided by `dur_ph`.

# %%
vowels_norm["RTime"] = vowels_norm["Interval"]/vowels_norm["dur_ph"]
vowels_norm.head()
# Out:
#   Participant Vowel   Time  Interval           F1           F2           F3  \
# 0        s001     e  0.069     0.002  2094.613890  2623.550627  3466.018273
# 1        s001     e  0.071     0.004  2094.042033  2624.005423  3465.626251
# 2        s001     e  0.073     0.006  2093.470176  2624.460218  3465.234230
# 3        s001     e  0.075     0.008  2092.898319  2624.915013  3464.842209
# 4        s001     e  0.077     0.010  2092.326462  2625.369809  3464.450187
#
#   Gender    Corpus  t1_ph  ...  next_ph Speech Rate  stress_vowel  vowel_ind  \
# 0   Male  DIMEx100  0.067  ...        n    2.167846             0          0
# 1   Male  DIMEx100  0.067  ...        n    2.167846             0          0
# 2   Male  DIMEx100  0.067  ...        n    2.167846             0          0
# 3   Male  DIMEx100  0.067  ...        n    2.167846             0          0
# 4   Male  DIMEx100  0.067  ...        n    2.167846             0          0
#
#      stress      F1_mid    Delta F   F1_norm   F2_norm     RTime
# 0  stressed  834.207032  977.31502  2.143233  2.684447  0.024096
# 1  stressed  834.207032  977.31502  2.142648  2.684913  0.048193
# 2  stressed  834.207032  977.31502  2.142063  2.685378  0.072289
# 3  stressed  834.207032  977.31502  2.141478  2.685843  0.096386
# 4  stressed  834.207032  977.31502  2.140893  2.686309  0.120482
#
# [5 rows x 29 columns]

# %% [markdown]
# Create a grouping factor that will uniquely identify each vowel produced by each speaker.

# %%
vowels_norm["unique"] = vowels_norm["fname"] + vowels_norm["t1_ph"].astype(str)

# %%
vowels_norm.to_csv("data/contour_norm.csv", index = False)
